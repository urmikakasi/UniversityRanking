# %%
import time 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import nltk 
import io 
import unicodedata 
import numpy as np 
import re 
import csv
import string 
from numpy import linalg 
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.tokenize import PunktSentenceTokenizer 
from nltk.tokenize import PunktSentenceTokenizer 
from nltk.corpus import webtext 
from nltk.stem.porter import PorterStemmer 
from nltk.stem.wordnet import WordNetLemmatizer

# %%
with open('res.csv') as f: 
    reader=csv.reader(f)
df=pd.read_csv('res.csv')

iitk=df[313:]
iitk=iitk[['timestamp','name','message','review','reviewNote']]
    
iitk
# Out:
#                     timestamp                    name  \
# 313  2020-06-12T08:13:55.352Z          Ashirvad Verma
# 314  2020-06-12T08:13:55.352Z            Suresh Singh
# 315  2020-06-12T08:13:55.352Z          Akshay Thengne
# 316  2020-06-12T08:13:55.352Z      Bharat KumarPandey
# 317  2020-06-12T08:13:55.352Z          Shambhavi Dube
# 318  2020-06-12T08:13:55.352Z            Anmol Dhawan
# 319  2020-06-12T08:13:55.352Z  Debyani Chattopadhyaya
# 320  2020-06-12T08:13:55.352Z           Mahesh Dulani
# 321  2020-06-12T08:13:55.352Z             Hashim Khan
# 322  2020-06-12T08:13:55.352Z            Avinash Jain
# 323  2020-06-12T08:13:55.352Z      Santosh Srivastava
# 324  2020-06-12T08:13:55.352Z               Rajni Jha
# 325  2020-06-12T08:13:55.352Z           Sandeep Kumar
# 326  2020-06-12T08:13:55.352Z     Hemanth Sharma Gade
# 327  2020-06-12T08:13:55.352Z         Ajay Kumar Mina
# 328  2020-06-12T08:13:55.352Z             Shivam Puri
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
vals=[]
#print(iitb)
df=iitk[['message','review','reviewNote']]
#print(df)
for index,row in df.iterrows():
    v=row["message"]
    #print(row)
    if isinstance(v,float):
        y=row["review"]
        #print(y)
        x=re.search("(recommends)",str(y))
        #print(x)
        z=re.search("(reviewed)",str(y))
        
        if x is not None:
            vals.append(0.05)
        
        elif z is not None:
            print(z.string)
            num=re.search('[5|4|3|2|1]',z.string)
            print(num.group())
            if num.group()=='5':
                vals.append(0.3)
            elif num.group()=='4':
                vals.append(0.1)
            elif num.group()=='3':
                vals.append(0)
            elif num.group()=='2':
                vals.append(-0.1)
            elif num.group()=='1':
                vals.append(-0.3)
            #vals.append(0.05)
        if x is None and z is None:
            vals.append(-0.05)
            
        #iitb['compound']=0
        #vals.append(0)
        
    else:
        
        val=analyzer.polarity_scores(v)['compound']
        vals.append(val)
#print(vals)
iitk['compound'] = vals
# Out:
# Dèêpű Gûptã Pîyúšh reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Sahil Kalra reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Lyci George reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Varsha Lohani reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Harshit Verma reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Aditya Singh reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Navin Manaswi reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Mohammad Masihuddin reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Anant Mundra reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Rajat Gupta reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Ashish Singh reviewed Indian Institute of Technology Kanpur – 1 star
# 1
# Manish Duhan reviewed Indian Institute of Technology Kanpur – 5 star
# 5
# Rahul Sharma reviewed Indian Institute of Technology Kanpur – 5 star
