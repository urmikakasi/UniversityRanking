# %%
import json
import csv
import tweepy
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
import GetOldTweets3 as got
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
import numpy as np

# %%
consumer_key = input()
consumer_secret = input()
access_key = input()
access_secret = input()
# Out:
# BZCiEnipIjwlIr5qdFawFL7Ka
# UTHnBo6nzb5HhsQGoFxjEHBHArDAlT9VyXx8x98AObzpV6iArr
# 757468675414695936-wVM842i23t6yTUDhbwuKkH92LGnZRAq
# TEFpzrCMH8aYl7YURiygG6Mgk76BAM9tLNWagI8JBAHiZ

# %%
june2019 = pd.read_json("june_iitb_tweets.json")
july2019 = pd.read_json("july_iitb_tweets.json")
aug2019 = pd.read_json("aug_iitb_tweets.json")
sept2019 = pd.read_json("sept_iitb_tweets.json")
oct2019 = pd.read_json("oct_iitb_tweets.json")
nov2019 = pd.read_json("nov_iitb_tweets.json")
dec2019 = pd.read_json("dec_iitb_tweets.json")
jan2020 = pd.read_json("jan2020_iitb_tweets.json")
feb2020 = pd.read_json("feb2020_iitb_tweets.json")
mar2020 = pd.read_json("mar2020_iitb_tweets.json")
apr2020 = pd.read_json("april2020_iitb_tweets.json")
may2020 = pd.read_json("may2020_iitb_tweets.json")
june2020 = pd.read_json("june2020_iitb_tweets.json")

# %%
frames = [june2019,july2019,aug2019,sept2019,oct2019,nov2019,dec2019,jan2020,feb2020,mar2020,apr2020,may2020,june2020]
tw_df = pd.concat(frames)
tweets_df = tw_df[['hashtags','timestamp','text','screen_name']]

# %%
tweets_df
# Out:
#                              hashtags           timestamp  \
# 0                        [KathuaRape] 2019-06-08 19:45:56
# 1                                  [] 2019-06-08 19:12:35
# 2                                  [] 2019-06-08 19:12:05
# 3                                  [] 2019-06-08 18:59:07
# 4     [microplastics, worldoceansday] 2019-06-08 18:17:58
# ...                               ...                 ...
# 2138                               [] 2020-06-10 01:00:25
# 2139                               [] 2020-06-10 00:32:20
# 2140                               [] 2020-06-10 00:30:22
# 2141                               [] 2020-06-10 00:17:39
# 2142                       [SARSCov2] 2020-06-10 00:15:48
#
#                                                    text     screen_name
# 0     The humanities department of @iitbombay had co...          ajhay9
# 1     iit bombay problem heard , which salt is good ...     satishgmatt
# 2     The energy burden that goes unaudited. Our wor...   ronitabardhan
# 3     Dr. Puniyani is great and will fight for truth...  ChackoattukadJ
# 4     The study of @iitbombay shows that every brand...   CitizenKamran
# ...                                                 ...             ...
# 2138  Time to talk with New Yorker's on Social Dista...         prjeusa
# 2139  IIT Bombay is India’s top university, says 202...       DrRahul_G
# 2140  from the abstract of this paper i have no idea...      jc96531326
# 2141  That's a hella small sample size and a pretty ...    Techbropolis
# 2142  Marked differences in survival, drying time fo...       EricTopol
#
# [49086 rows x 4 columns]

# %%
tweets_df = tweets_df.reset_index()

# %%
#check how many tweets were from one of the university handles
uni_tweets = tweets_df.loc[tweets_df['screen_name'].isin(['iitbombay','ecell_iitb','idc_iitb','edtechiitb'])]

# %%
uni_tweets['uni_handle'] = 1
# Out:
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
uni_tweets
#uni_handle_list =  ['iitmadras','ecelliitm','vandemataramiit','iGEM_IITM','iitm_respark','domsiitmadras','emliitm','iitmbt','CFI_IITM','iitmfoundation']
# Out:
#        index                                           hashtags  \
# 58        58                                                 []
# 77        77                                                 []
# 141      141                                                 []
# 142      142                                                 []
# 226      226                                                 []
# ...      ...                                                ...
# 47391    448                                                 []
# 47701    758                                                 []
# 48167   1224                            [Proud_to_be_Indianpic]
# 48480   1537  [Connect_Learn_Grow, CAProgramLaunched, Regist...
# 48659   1716                                                 []
#
#                 timestamp                                               text  \
# 58    2019-06-10 04:36:29  IIT Bombay congratulates our alumnus Mr. Abida...
# 77    2019-06-10 04:36:29  IIT Bombay congratulates our alumnus Mr. Abida...
# 141   2019-06-18 05:01:00  Professor Sridhar Balasubramanian, an associat...
# 142   2019-06-18 05:01:00  Professor Sridhar Balasubramanian, an associat...
# 226   2019-06-27 05:13:39  In order to create more awareness about solar ...
# ...                   ...                                                ...
# 47391 2020-06-15 08:30:14  E-Cell IIT Bombay is proud to host a webinar w...
# 47701 2020-06-06 07:32:14  Kudos to team from IIT Bombay!\nhttps://www.hi...
# 48167 2020-06-12 11:53:56  E-Cell, IIT Bombay congratulates Kiran Mazumda...
# 48480 2020-06-03 06:47:18  Presenting the E-Cell IIT Bombay's Campus Amba...
# 48659 2020-06-11 09:19:45  IIT Bombay is ranked 3rd in engineering catego...
#
#       screen_name  uni_handle
# 58      iitbombay           1
# 77      iitbombay           1
# 141     iitbombay           1
# 142     iitbombay           1
# 226     iitbombay           1
# ...           ...         ...
# 47391  ecell_iitb           1
# 47701   iitbombay           1
# 48167  ecell_iitb           1
# 48480  ecell_iitb           1
# 48659   iitbombay           1
#
# [419 rows x 6 columns]

# %%
tweets_df['uni_handle'] = uni_tweets['uni_handle']

# %%
iitb = tweets_df.combine_first(tweets_df)
iitb
# Out:
#        index                         hashtags           timestamp  \
# 0          0                     [KathuaRape] 2019-06-08 19:45:56
# 1          1                               [] 2019-06-08 19:12:35
# 2          2                               [] 2019-06-08 19:12:05
# 3          3                               [] 2019-06-08 18:59:07
# 4          4  [microplastics, worldoceansday] 2019-06-08 18:17:58
# ...      ...                              ...                 ...
# 49081   2138                               [] 2020-06-10 01:00:25
# 49082   2139                               [] 2020-06-10 00:32:20
# 49083   2140                               [] 2020-06-10 00:30:22
# 49084   2141                               [] 2020-06-10 00:17:39
# 49085   2142                       [SARSCov2] 2020-06-10 00:15:48
#
#                                                     text     screen_name  \
# 0      The humanities department of @iitbombay had co...          ajhay9
# 1      iit bombay problem heard , which salt is good ...     satishgmatt
# 2      The energy burden that goes unaudited. Our wor...   ronitabardhan
# 3      Dr. Puniyani is great and will fight for truth...  ChackoattukadJ
# 4      The study of @iitbombay shows that every brand...   CitizenKamran
# ...                                                  ...             ...
# 49081  Time to talk with New Yorker's on Social Dista...         prjeusa
# 49082  IIT Bombay is India’s top university, says 202...       DrRahul_G
# 49083  from the abstract of this paper i have no idea...      jc96531326
# 49084  That's a hella small sample size and a pretty ...    Techbropolis
# 49085  Marked differences in survival, drying time fo...       EricTopol
#
#        uni_handle
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 49081         NaN
# 49082         NaN
# 49083         NaN
# 49084         NaN
# 49085         NaN
#
# [49086 rows x 6 columns]

# %%
iitb[iitb['uni_handle'] == 1]
# Out:
#        index                                           hashtags  \
# 58        58                                                 []
# 77        77                                                 []
# 141      141                                                 []
# 142      142                                                 []
# 226      226                                                 []
# ...      ...                                                ...
# 47391    448                                                 []
# 47701    758                                                 []
# 48167   1224                            [Proud_to_be_Indianpic]
# 48480   1537  [Connect_Learn_Grow, CAProgramLaunched, Regist...
# 48659   1716                                                 []
#
#                 timestamp                                               text  \
# 58    2019-06-10 04:36:29  IIT Bombay congratulates our alumnus Mr. Abida...
# 77    2019-06-10 04:36:29  IIT Bombay congratulates our alumnus Mr. Abida...
# 141   2019-06-18 05:01:00  Professor Sridhar Balasubramanian, an associat...
# 142   2019-06-18 05:01:00  Professor Sridhar Balasubramanian, an associat...
# 226   2019-06-27 05:13:39  In order to create more awareness about solar ...
# ...                   ...                                                ...
# 47391 2020-06-15 08:30:14  E-Cell IIT Bombay is proud to host a webinar w...
# 47701 2020-06-06 07:32:14  Kudos to team from IIT Bombay!\nhttps://www.hi...
# 48167 2020-06-12 11:53:56  E-Cell, IIT Bombay congratulates Kiran Mazumda...
# 48480 2020-06-03 06:47:18  Presenting the E-Cell IIT Bombay's Campus Amba...
# 48659 2020-06-11 09:19:45  IIT Bombay is ranked 3rd in engineering catego...
#
#       screen_name  uni_handle
# 58      iitbombay         1.0
# 77      iitbombay         1.0
# 141     iitbombay         1.0
# 142     iitbombay         1.0
# 226     iitbombay         1.0
# ...           ...         ...
# 47391  ecell_iitb         1.0
# 47701   iitbombay         1.0
# 48167  ecell_iitb         1.0
# 48480  ecell_iitb         1.0
# 48659   iitbombay         1.0
#
# [419 rows x 6 columns]

# %%
iitb['uni_handle'] = iitb['uni_handle'].replace(np.nan, 0)

# %%
iitb[iitb['uni_handle'] == 1]
# Out:
#        index                                           hashtags  \
# 58        58                                                 []
# 77        77                                                 []
# 141      141                                                 []
# 142      142                                                 []
# 226      226                                                 []
# ...      ...                                                ...
# 47391    448                                                 []
# 47701    758                                                 []
# 48167   1224                            [Proud_to_be_Indianpic]
# 48480   1537  [Connect_Learn_Grow, CAProgramLaunched, Regist...
# 48659   1716                                                 []
#
#                 timestamp                                               text  \
# 58    2019-06-10 04:36:29  IIT Bombay congratulates our alumnus Mr. Abida...
# 77    2019-06-10 04:36:29  IIT Bombay congratulates our alumnus Mr. Abida...
# 141   2019-06-18 05:01:00  Professor Sridhar Balasubramanian, an associat...
# 142   2019-06-18 05:01:00  Professor Sridhar Balasubramanian, an associat...
# 226   2019-06-27 05:13:39  In order to create more awareness about solar ...
# ...                   ...                                                ...
# 47391 2020-06-15 08:30:14  E-Cell IIT Bombay is proud to host a webinar w...
# 47701 2020-06-06 07:32:14  Kudos to team from IIT Bombay!\nhttps://www.hi...
# 48167 2020-06-12 11:53:56  E-Cell, IIT Bombay congratulates Kiran Mazumda...
# 48480 2020-06-03 06:47:18  Presenting the E-Cell IIT Bombay's Campus Amba...
# 48659 2020-06-11 09:19:45  IIT Bombay is ranked 3rd in engineering catego...
#
#       screen_name  uni_handle
# 58      iitbombay         1.0
# 77      iitbombay         1.0
# 141     iitbombay         1.0
# 142     iitbombay         1.0
# 226     iitbombay         1.0
# ...           ...         ...
# 47391  ecell_iitb         1.0
# 47701   iitbombay         1.0
# 48167  ecell_iitb         1.0
# 48480  ecell_iitb         1.0
# 48659   iitbombay         1.0
#
# [419 rows x 6 columns]

# %%
#dataframe containing additional column uni_handle (1 if it is a handle of the university else 0)
#iitm[iitm['uni_handle'] == 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-9bb908551bb6> in <module>
#       2 #iitm[iitm['uni_handle'] == 0]
#       3
# ----> 4 iitb_final
#
# NameError: name 'iitb_final' is not defined

# %%
#Finding sentiment of the tweets using VADER
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
iitb['compound'] = [analyzer.polarity_scores(v)['compound'] for v in iitb['text']]

# %%
iitb
# Out:
#                                               Tweet_text  \
# 0      #OnThisDay in 1831, James Clerk Maxwell was bo...
# 1      This being the only courier service in the are...
# 2      And QS world University ranking to standing of...
# 3      Please Help Us #Students .Please extend Date o...
# 4      @Techfest_IITB remembers Dr. John Forbes Nash ...
# ...                                                  ...
# 11936  TIME PASS.... Ask them to quit IIM and then pr...
# 11937  Must watch. Epic! https://youtu.be/CEpRccgc9G0...
# 11938  yes, IIT D, IIT BOMBAY, IIT MADRAS, IIT KANPUR...
# 11939  IIT Bombay Beckons you to attend an alumni reu...
# 11940  When will India develop this advanced weapons?...
#
#                            date         username  retweets  uni_handle  \
# 0     2020-06-13 13:36:43+00:00    Techfest_IITB        19         0.0
# 1     2020-06-13 13:31:12+00:00  Karthik38561419         0         0.0
# 2     2020-06-13 11:44:07+00:00  Ashutos55613937         0         0.0
# 3     2020-06-13 11:27:36+00:00  Himansh18811460         1         0.0
# 4     2020-06-13 11:11:54+00:00    Techfest_IITB        28         0.0
# ...                         ...              ...       ...         ...
# 11936 2020-01-01 05:36:16+00:00          hemmu25         0         0.0
# 11937 2020-01-01 04:57:35+00:00     ApoorvanandJ         0         0.0
# 11938 2020-01-01 04:52:50+00:00  ProudToBeJamian         0         0.0
# 11939 2020-01-01 03:37:30+00:00  debeshchoudhury         0         0.0
# 11940 2020-01-01 00:31:00+00:00   rewatiramanray         0         0.0
#
#        compound
# 0        0.6369
# 1        0.3612
# 2        0.0000
# 3        0.8519
# 4        0.0000
# ...         ...
# 11936   -0.2500
# 11937    0.0000
# 11938    0.9167
# 11939    0.6166
# 11940    0.2240
#
# [11941 rows x 6 columns]

# %%
#classifying sentiments as positive,negative and neutral
def sentiment(compound):
    res = ""
    if(compound >= 0.05):
        res="Positive"
    elif(compound <= - 0.05):
        res="Negative"
    else:
        res="Neutral"
    return res

iitb['Sentiment'] = iitb['compound'].apply(lambda x: sentiment(x))

# %%
iitb
# Out:
#        index                         hashtags           timestamp  \
# 0          0                     [KathuaRape] 2019-06-08 19:45:56
# 1          1                               [] 2019-06-08 19:12:35
# 2          2                               [] 2019-06-08 19:12:05
# 3          3                               [] 2019-06-08 18:59:07
# 4          4  [microplastics, worldoceansday] 2019-06-08 18:17:58
# ...      ...                              ...                 ...
# 49081   2138                               [] 2020-06-10 01:00:25
# 49082   2139                               [] 2020-06-10 00:32:20
# 49083   2140                               [] 2020-06-10 00:30:22
# 49084   2141                               [] 2020-06-10 00:17:39
# 49085   2142                       [SARSCov2] 2020-06-10 00:15:48
#
#                                                     text     screen_name  \
# 0      The humanities department of @iitbombay had co...          ajhay9
# 1      iit bombay problem heard , which salt is good ...     satishgmatt
# 2      The energy burden that goes unaudited. Our wor...   ronitabardhan
# 3      Dr. Puniyani is great and will fight for truth...  ChackoattukadJ
# 4      The study of @iitbombay shows that every brand...   CitizenKamran
# ...                                                  ...             ...
# 49081  Time to talk with New Yorker's on Social Dista...         prjeusa
# 49082  IIT Bombay is India’s top university, says 202...       DrRahul_G
# 49083  from the abstract of this paper i have no idea...      jc96531326
# 49084  That's a hella small sample size and a pretty ...    Techbropolis
# 49085  Marked differences in survival, drying time fo...       EricTopol
#
#        uni_handle  compound Sentiment
# 0             0.0   -0.6369  Negative
# 1             0.0    0.7003  Positive
# 2             0.0   -0.2023  Negative
# 3             0.0    0.9300  Positive
# 4             0.0   -0.7906  Negative
# ...           ...       ...       ...
# 49081         0.0    0.0000   Neutral
# 49082         0.0    0.2023  Positive
# 49083         0.0   -0.2960  Negative
# 49084         0.0    0.2263  Positive
# 49085         0.0   -0.4939  Negative
#
# [49086 rows x 8 columns]

# %%
iitb.to_csv('final_iitb.csv',index=False)

# %%
# Out:
# 11941
