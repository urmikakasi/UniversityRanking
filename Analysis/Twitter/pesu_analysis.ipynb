# %%
import json
import csv
import tweepy
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
import GetOldTweets3 as got
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os
from textwrap import wrap
import plotly_express as px

# %%
# Set default fontsize and colors for graphs
SMALL_SIZE, MEDIUM_SIZE, BIG_SIZE = 10, 12, 20
plt.rc('font', size=MEDIUM_SIZE)       
plt.rc('axes', titlesize=BIG_SIZE)     
plt.rc('axes', labelsize=MEDIUM_SIZE)  
plt.rc('xtick', labelsize=MEDIUM_SIZE) 
plt.rc('ytick', labelsize=MEDIUM_SIZE) 
plt.rc('legend', fontsize=SMALL_SIZE)  
plt.rc('figure', titlesize=BIG_SIZE)
my_colors = 'rgbkymc'

# Disable scrolling for long output
from IPython.display import display, Javascript
disable_js = """
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
}
"""
display(Javascript(disable_js))

# %%
df=pd.read_csv('final_pesu.csv')
wn = nltk.WordNetLemmatizer()
df=df.drop(columns="Unnamed: 0")
df
# Out:
#                                                    text  \
# 0     Here it is a full link of Nerpada pesu @PTTVOn...
# 1     • Guys, here is the tag  #SuriyaFCWarnsBJPnADM...
# 2     @karthickselvaa hope will discuss about this p...
# 3     Speak a few words friendly to Meera during her...
# 4     What were you doing at MCdonlad ? Lootay huy p...
# 5     Here it is a full link of Nerpada pesu @PTTVOn...
# 6     • Guys, here is the tag  #SuriyaFCWarnsBJPnADM...
# 7     @karthickselvaa hope will discuss about this p...
# 8     Speak a few words friendly to Meera during her...
# 9     What were you doing at MCdonlad ? Lootay huy p...
# 10                                     Thank you pesu!!
# 11        Type nerpada pesu at you tube its available..
# 12    Just type nerpada pesu at youtube you will get...
# 13    Dai arivu ketta pu... don't you have sense... ...
# 14    Looks like the news channels are running out o...
# 15                                     Thank you pesu!!
# 16        Type nerpada pesu at you tube its available..
# 17    Just type nerpada pesu at youtube you will get...
# 18    Dai arivu ketta pu... don't you have sense... ...
# 19    Looks like the news channels are running out o...
# 20    I found this awesome recording of "Kanmaniye P...
# 21    First onnu olunga pesu.. selling price 80 cr n...
# 22    C'mon mchn pesu Amma ..appa ..uncle.... aunty ...
# 23     Po da publicity paithiyam first respect aaa pesu
# 24    I am all for freedom of expression why does on...
# 25    I found this awesome recording of "Kanmaniye P...
# 26    First onnu olunga pesu.. selling price 80 cr n...
# 27    C'mon mchn pesu Amma ..appa ..uncle.... aunty ...
# 28     Po da publicity paithiyam first respect aaa pesu
# 29    I am all for freedom of expression why does on...
# ...                                                 ...
# 1826  @PESUniversity My sister is studying in your l...
# 1827  *#PES UNIVERSITY*\n#Direct admission in PES #U...
# 1828  WarrenBuffett Hello sir,\nI'm Raiba Bhosale, m...
# 1829  @WarrenBuffett Hello sir,\nI'm Raiba Bhosale, ...
# 1830  Clefhangers team win at city’s techno-cultural...
# 1831  $! PES University#\n@Direct #admission in #PES...
# 1832  PES University Admission 2020: Application (St...
# 1833  PESSAT 2020 Exam – Registration, Dates, Eligib...
# 1834  I shoot people. @ PES University https://www.i...
# 1835  Young innovators from PES University, Bengalur...
# 1836  PES University Admission 2020: Application (St...
# 1837  PESSAT 2020 Exam – Registration, Dates, Eligib...
# 1838  I shoot people. @ PES University https://www.i...
# 1839  Young innovators from PES University, Bengalur...
# 1840  PES University in the Media: Tech education ca...
# 1841  #PES UNIVERSITY @admission Bangalore 2020\nPES...
# 1842  Management quota Admission in Pes University c...
# 1843  PES University in the Media: Coronavirus a sho...
# 1844  Burning down @PESUniversity pic.twitter.com/Uf...
# 1845  supritha_shivakumar \nchinzz.12 \n\n#enlighten...
# 1846  #Direct admission in @PES UNIVERSITY\n@Admissi...
# 1847  PES University in the Media: Tech education ca...
# 1848  #PES UNIVERSITY @admission Bangalore 2020\nPES...
# 1849  Management quota Admission in Pes University c...
# 1850  PES University in the Media: Coronavirus a sho...
# 1851  Burning down @PESUniversity pic.twitter.com/Uf...
# 1852  supritha_shivakumar \nchinzz.12 \n\n#enlighten...
# 1853  #Direct admission in @PES UNIVERSITY\n@Admissi...
# 1854  PES University Admission 2020: Application (St...
# 1855  PES University Admission 2020: Application (St...
#
#                           username             tweet_id            timestamp  \
# 0          SURIYA FANS CLUB -SALEM  1150816351470010368  2019-07-15 17:16:13
# 1     ®anjith SF©™✈Soorarai Pottru  1150766936008978432  2019-07-15 13:59:52
# 2              Kanthi Mathi Nathan  1150705572649394176  2019-07-15 09:56:02
# 3                      Kiddy Vijay  1150620271717449728  2019-07-15 04:17:04
# 4                     Sohail Shami  1150102123356610560  2019-07-13 17:58:08
# 5          SURIYA FANS CLUB -SALEM  1150816351470010368  2019-07-15 17:16:13
# 6     ®anjith SF©™✈Soorarai Pottru  1150766936008978432  2019-07-15 13:59:52
# 7              Kanthi Mathi Nathan  1150705572649394176  2019-07-15 09:56:02
# 8                      Kiddy Vijay  1150620271717449728  2019-07-15 04:17:04
# 9                     Sohail Shami  1150102123356610560  2019-07-13 17:58:08
# 10                           erica  1141703346773880832  2019-06-20 13:44:24
# 11            சூர்யா@தமிழ் பிரியன்  1141612062595878912  2019-06-20 07:41:40
# 12            சூர்யா@தமிழ் பிரியன்  1141392402516590592  2019-06-19 17:08:49
# 13                    Riyaz ahamed  1141353308574982144  2019-06-19 14:33:28
# 14               EEEINDHIIYAAAAAAA  1141344705080254464  2019-06-19 13:59:17
# 15                           erica  1141703346773880832  2019-06-20 13:44:24
# 16            சூர்யா@தமிழ் பிரியன்  1141612062595878912  2019-06-20 07:41:40
# 17            சூர்யா@தமிழ் பிரியன்  1141392402516590592  2019-06-19 17:08:49
# 18                    Riyaz ahamed  1141353308574982144  2019-06-19 14:33:28
# 19               EEEINDHIIYAAAAAAA  1141344705080254464  2019-06-19 13:59:17
# 20                           Vivek  1138851256556957696  2019-06-12 16:51:13
# 21     #Karthik 𝓣𝓱𝓪𝓵𝓪𝓹𝓪𝓽𝓱𝔂𝓥𝓲𝓳𝓪𝔂46👑  1138347089031655424  2019-06-11 07:27:50
# 22                   Pugazh VJ❤️VK  1138329156326838272  2019-06-11 06:16:34
# 23                          Prabha  1138237487652851712  2019-06-11 00:12:19
# 24                The life saffron  1137962475549286400  2019-06-10 05:59:31
# 25                           Vivek  1138851256556957696  2019-06-12 16:51:13
# 26     #Karthik 𝓣𝓱𝓪𝓵𝓪𝓹𝓪𝓽𝓱𝔂𝓥𝓲𝓳𝓪𝔂46👑  1138347089031655424  2019-06-11 07:27:50
# 27                   Pugazh VJ❤️VK  1138329156326838272  2019-06-11 06:16:34
# 28                          Prabha  1138237487652851712  2019-06-11 00:12:19
# 29                The life saffron  1137962475549286400  2019-06-10 05:59:31
# ...                            ...                  ...                  ...
# 1826                Chhaya Taparia  1265896210642108416  2020-05-28 06:42:30
# 1827              himshekher singh  1265888325409234944  2020-05-28 06:11:10
# 1828    South Carolina Energy News  1265719421529702400  2020-05-27 19:00:00
# 1829                 Raiba Bhosale  1265719280307298304  2020-05-27 18:59:27
# 1830                PES University  1265656652419588096  2020-05-27 14:50:35
# 1831              himshekher singh  1265175516480368640  2020-05-26 06:58:43
# 1832                       Eduport  1261584038143365120  2020-05-16 09:07:28
# 1833               College Pravesh  1261364490316046336  2020-05-15 18:35:04
# 1834                Sreejith Reddy  1261318949695823872  2020-05-15 15:34:06
# 1835                  Unisys India  1261158214202200064  2020-05-15 04:55:24
# 1836                       Eduport  1261584038143365120  2020-05-16 09:07:28
# 1837               College Pravesh  1261364490316046336  2020-05-15 18:35:04
# 1838                Sreejith Reddy  1261318949695823872  2020-05-15 15:34:06
# 1839                  Unisys India  1261158214202200064  2020-05-15 04:55:24
# 1840                PES University  1271089308749795328  2020-06-11 14:38:01
# 1841              himshekher singh  1270952638704570368  2020-06-11 05:34:56
# 1842                  surjit kumar  1270689280587776000  2020-06-10 12:08:27
# 1843                PES University  1270367632835833856  2020-06-09 14:50:20
# 1844                            Am  1270274789278511104  2020-06-09 08:41:24
# 1845                           RCP  1270269779853672448  2020-06-09 08:21:30
# 1846              himshekher singh  1270243655865872384  2020-06-09 06:37:42
# 1847                PES University  1271089308749795328  2020-06-11 14:38:01
# 1848              himshekher singh  1270952638704570368  2020-06-11 05:34:56
# 1849                  surjit kumar  1270689280587776000  2020-06-10 12:08:27
# 1850                PES University  1270367632835833856  2020-06-09 14:50:20
# 1851                            Am  1270274789278511104  2020-06-09 08:41:24
# 1852                           RCP  1270269779853672448  2020-06-09 08:21:30
# 1853              himshekher singh  1270243655865872384  2020-06-09 06:37:42
# 1854                       Eduport  1262247242787848192  2020-05-18 05:02:48
# 1855                       Eduport  1262247242787848192  2020-05-18 05:02:48
#
#                                                hashtags      screen_name  \
# 0                        ['SuriyaFCWarnsBJPnADMKhttps']   Salem_sfc_offl
# 1                ['SuriyaFCWarnsBJPnADMK', 'Kadamboor']      Ranjith_SFC
# 2                                                    []         kanthi90
# 3                                    ['BiggBossTamil3']       KiddyVijay
# 4                                                    []  engineersohail3
# 5                        ['SuriyaFCWarnsBJPnADMKhttps']   Salem_sfc_offl
# 6                ['SuriyaFCWarnsBJPnADMK', 'Kadamboor']      Ranjith_SFC
# 7                                                    []         kanthi90
# 8                                    ['BiggBossTamil3']       KiddyVijay
# 9                                                    []  engineersohail3
# 10                                                   []      EricaRymndo
# 11                                                   []  Tamilpr69418381
# 12                                                   []  Tamilpr69418381
# 13                                                   []  Riyazah61126399
# 14                                                   []     Ohnomynameis
# 15                                                   []      EricaRymndo
# 16                                                   []  Tamilpr69418381
# 17                                                   []  Tamilpr69418381
# 18                                                   []  Riyazah61126399
# 19                                                   []     Ohnomynameis
# 20                                            ['Smule']    Vivek93864694
# 21                                                   []      sacvims1033
# 22                                                   []         pugazh98
# 23                                                   []      Prabhakavi_
# 24                                                   []   thelifesaffron
# 25                                            ['Smule']    Vivek93864694
# 26                                                   []      sacvims1033
# 27                                                   []         pugazh98
# 28                                                   []      Prabhakavi_
# 29                                                   []   thelifesaffron
# ...                                                 ...              ...
# 1826                                                 []   chhaya_taparia
# 1827  ['PES', 'Direct', 'UNIVERSITY', 'Admission', '...      HimshekherS
# 1828  ['renewableenergy', 'COVID19', 'cleanenergy', ...         scegnews
# 1829  ['renewableenergy', 'COVID19', 'cleanenergy', ...    bhosale_raiba
# 1830                                                 []    PESUniversity
# 1831           ['admission', 'PES', 'PES', 'Bangalore']      HimshekherS
# 1832                                                 []      Eduportplus
# 1833       ['EntranceExams', 'PESUniversity', 'PESSAT']   CollegePravesh
# 1834                                                 []         _vritra_
# 1835  ['Cloud2020Y11', 'InnovationFest', 'AmazingUni...      UnisysIndia
# 1836                                                 []      Eduportplus
# 1837       ['EntranceExams', 'PESUniversity', 'PESSAT']   CollegePravesh
# 1838                                                 []         _vritra_
# 1839  ['Cloud2020Y11', 'InnovationFest', 'AmazingUni...      UnisysIndia
# 1840                                                 []    PESUniversity
# 1841  ['PES', 'admission', 'management', 'Management...      HimshekherS
# 1842                                                 []  surjitk69266301
# 1843                                                 []    PESUniversity
# 1844                                                 []       amfalsegod
# 1845       ['enlighteninghumanlives', 'thankyouheroes']      rc_pesu3190
# 1846  ['Direct', 'UNIVERSITY', 'Admission', 'PES', '...      HimshekherS
# 1847                                                 []    PESUniversity
# 1848  ['PES', 'admission', 'management', 'Management...      HimshekherS
# 1849                                                 []  surjitk69266301
# 1850                                                 []    PESUniversity
# 1851                                                 []       amfalsegod
# 1852       ['enlighteninghumanlives', 'thankyouheroes']      rc_pesu3190
# 1853  ['Direct', 'UNIVERSITY', 'Admission', 'PES', '...      HimshekherS
# 1854                                                 []      Eduportplus
# 1855                                                 []      Eduportplus
#
#       retweets  uni_handle  compound Sentiment
# 0            6         0.0    0.0000   Neutral
# 1           47         0.0   -0.4184  Negative
# 2            0         0.0    0.4404  Positive
# 3            0         0.0    0.9656  Positive
# 4            0         0.0    0.0000   Neutral
# 5            6         0.0    0.0000   Neutral
# 6           47         0.0   -0.4184  Negative
# 7            0         0.0    0.4404  Positive
# 8            0         0.0    0.9656  Positive
# 9            0         0.0    0.0000   Neutral
# 10           0         0.0    0.4738  Positive
# 11           0         0.0    0.0000   Neutral
# 12           0         0.0    0.0000   Neutral
# 13           0         0.0   -0.2824  Negative
# 14           0         0.0    0.2003  Positive
# 15           0         0.0    0.4738  Positive
# 16           0         0.0    0.0000   Neutral
# 17           0         0.0    0.0000   Neutral
# 18           0         0.0   -0.2824  Negative
# 19           0         0.0    0.2003  Positive
# 20           0         0.0    0.7073  Positive
# 21           0         0.0    0.7870  Positive
# 22           0         0.0    0.4215  Positive
# 23           0         0.0   -0.1280  Negative
# 24           0         0.0    0.8555  Positive
# 25           0         0.0    0.7073  Positive
# 26           0         0.0    0.7870  Positive
# 27           0         0.0    0.4215  Positive
# 28           0         0.0   -0.1280  Negative
# 29           0         0.0    0.8555  Positive
# ...        ...         ...       ...       ...
# 1826         0         0.0    0.0000   Neutral
# 1827         0         0.0    0.0000   Neutral
# 1828         0         0.0    0.7430  Positive
# 1829         0         0.0    0.7430  Positive
# 1830         0         1.0    0.8176  Positive
# 1831         0         0.0    0.0000   Neutral
# 1832         0         0.0    0.0000   Neutral
# 1833         0         0.0    0.0000   Neutral
# 1834         0         0.0   -0.3400  Negative
# 1835         0         0.0    0.8689  Positive
# 1836         0         0.0    0.0000   Neutral
# 1837         0         0.0    0.0000   Neutral
# 1838         0         0.0   -0.3400  Negative
# 1839         0         0.0    0.8689  Positive
# 1840         0         1.0    0.3818  Positive
# 1841         0         0.0    0.0000   Neutral
# 1842         1         0.0    0.0000   Neutral
# 1843         0         1.0    0.2732  Positive
# 1844         0         0.0    0.0000   Neutral
# 1845         0         0.0    0.0000   Neutral
# 1846         0         0.0    0.0000   Neutral
# 1847         0         1.0    0.3818  Positive
# 1848         0         0.0    0.0000   Neutral
# 1849         1         0.0    0.0000   Neutral
# 1850         0         1.0    0.2732  Positive
# 1851         0         0.0    0.0000   Neutral
# 1852         0         0.0    0.0000   Neutral
# 1853         0         0.0    0.0000   Neutral
# 1854         0         0.0    0.0000   Neutral
# 1855         0         0.0    0.0000   Neutral
#
# [1856 rows x 10 columns]

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 935 entries, 0 to 1854
# Data columns (total 10 columns):
# text           935 non-null object
# username       935 non-null object
# tweet_id       935 non-null int64
# timestamp      935 non-null object
# hashtags       935 non-null object
# screen_name    935 non-null object
# retweets       935 non-null int64
# uni_handle     935 non-null float64
# compound       935 non-null float64
# Sentiment      935 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 80.4+ KB

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format = "%d/%m/%Y", utc  = False)

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
df["monthName"] = df.timestamp.dt.month_name()
data = df["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of tweets by Month')

df["dayName"] = df.timestamp.dt.day_name()
data = df["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of tweets by Days of Week')

plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,6))
df["dayOfMonth"] = df.timestamp.dt.day
data = df["dayOfMonth"].value_counts(normalize=True).sort_index()
axes.bar(data.index, data, color='pink', width=0.5, zorder=0)
axes.plot(data.index, data, color='red', zorder=1)
axes.scatter(data.index, data, s=50, color='darkred', zorder=2)

axes.set_xlabel('Date of Month')
axes.set_xticks(np.arange(1, 32))
axes.set_xticklabels([str(val) for val in np.arange(1, 32)])
axes.set_ylim(0, 0.1)
axes.set_title('% of tweets by Date of Month')

plt.show()

# %%
import string
def clean_text(text):
    text_lc = "".join([word.lower() for word in text if word not in string.punctuation]) # remove puntuation
    text_rc = re.sub('[0-9]+', '', text_lc)
    nopunc = re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))', '', text_rc) #remove urls
    nopunc = re.sub(r'http\S+', '', nopunc) #remove usernames
    nopunc = re.sub(r'#([^\s]+)', r'\1', nopunc) #remove hashtags
    nopunc= re.sub(r'(.)\1+', r'\1\1', nopunc)  #remove repeating characters 
    tokens = re.split('\W+', nopunc)    # tokenization
    text = [word for word in tokens if word not in stopwords]  # remove stopwords and stemming
    return text
df['Text_cleaned'] = df['text'].apply(lambda x: clean_text(x))

# %%
def lemmatizer(text):
    text = [wn.lemmatize(word) for word in text]
    return text
df['Text_lemmatized'] = df['Text_cleaned'].apply(lambda x: lemmatizer(x))

def listtostr(s):
    str1=" "
    return (str1.join(s))
df['Text_lemmatized_str'] = df['Text_lemmatized'].apply(lambda x: listtostr(x))
df.head()
# Out:
#                                                 text  \
# 0  Here it is a full link of Nerpada pesu @PTTVOn...
# 1  • Guys, here is the tag  #SuriyaFCWarnsBJPnADM...
# 2  @karthickselvaa hope will discuss about this p...
# 3  Speak a few words friendly to Meera during her...
# 4  What were you doing at MCdonlad ? Lootay huy p...
#
#                        username             tweet_id           timestamp  \
# 0       SURIYA FANS CLUB -SALEM  1150816351470010368 2019-07-15 17:16:13
# 1  ®anjith SF©™✈Soorarai Pottru  1150766936008978432 2019-07-15 13:59:52
# 2           Kanthi Mathi Nathan  1150705572649394176 2019-07-15 09:56:02
# 3                   Kiddy Vijay  1150620271717449728 2019-07-15 04:17:04
# 4                  Sohail Shami  1150102123356610560 2019-07-13 17:58:08
#
#                                  hashtags      screen_name  retweets  \
# 0          ['SuriyaFCWarnsBJPnADMKhttps']   Salem_sfc_offl         6
# 1  ['SuriyaFCWarnsBJPnADMK', 'Kadamboor']      Ranjith_SFC        47
# 2                                      []         kanthi90         0
# 3                      ['BiggBossTamil3']       KiddyVijay         0
# 4                                      []  engineersohail3         0
#
#    uni_handle  compound Sentiment monthName   dayName  dayOfMonth  \
# 0         0.0    0.0000   Neutral      July    Monday          15
# 1         0.0   -0.4184  Negative      July    Monday          15
# 2         0.0    0.4404  Positive      July    Monday          15
# 3         0.0    0.9656  Positive      July    Monday          15
# 4         0.0    0.0000   Neutral      July  Saturday          13
#
#                                         Text_cleaned  \
# 0  [full, link, nerpada, pesu, pttvonlinenews, ch...
# 1  [, guys, tag, suriyafcwarnsbjpnadmk, every, ci...
# 2  [karthickselvaa, hope, discuss, program, namec...
# 3  [speak, words, friendly, meera, paris, corner,...
# 4  [mcdonlad, lootay, huy, pesu, k, kha, rhay, ho, ]
#
#                                      Text_lemmatized  \
# 0  [full, link, nerpada, pesu, pttvonlinenews, ch...
# 1  [, guy, tag, suriyafcwarnsbjpnadmk, every, cit...
# 2  [karthickselvaa, hope, discus, program, nameca...
# 3  [speak, word, friendly, meera, paris, corner, ...
# 4  [mcdonlad, lootay, huy, pesu, k, kha, rhay, ho, ]
#
#                                  Text_lemmatized_str
# 0  full link nerpada pesu pttvonlinenews chief su...
# 1   guy tag suriyafcwarnsbjpnadmk every citizen r...
# 2  karthickselvaa hope discus program namecalled ...
# 3  speak word friendly meera paris corner time ge...
# 4            mcdonlad lootay huy pesu k kha rhay ho

# %%
pos_df = df[df.Sentiment == 'Positive']
neg_df = df[df.Sentiment == 'Negative']
neu_df = df[df.Sentiment == 'Neutral']

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
data = pos_df["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of positive tweets by Month')

data = pos_df["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of positive tweets by Days of Week')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
data = neg_df["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of Negative tweets by Month')

data = neg_df["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of Negative tweets by Days of Week')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
data = neu_df["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of Neutral tweets by Month')

data = neu_df["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of Neutral tweets by Days of Week')

plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,6))
data = pos_df["dayOfMonth"].value_counts(normalize=True).sort_index()
axes.bar(data.index, data, color='pink', width=0.5, zorder=0)
axes.plot(data.index, data, color='red', zorder=1)
axes.scatter(data.index, data, s=50, color='darkred', zorder=2)

axes.set_xlabel('Date of Month')
axes.set_xticks(np.arange(1, 32))
axes.set_xticklabels([str(val) for val in np.arange(1, 32)])
axes.set_ylim(0, 0.1)
axes.set_title('% of Positive tweets by Date of Month')

plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,6))
data = neg_df["dayOfMonth"].value_counts(normalize=True).sort_index()
axes.bar(data.index, data, color='pink', width=0.5, zorder=0)
axes.plot(data.index, data, color='red', zorder=1)
axes.scatter(data.index, data, s=50, color='darkred', zorder=2)

axes.set_xlabel('Date of Month')
axes.set_xticks(np.arange(1, 32))
axes.set_xticklabels([str(val) for val in np.arange(1, 32)])
axes.set_ylim(0, 0.1)
axes.set_title('% of Negative tweets by Date of Month')

plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,6))
data = neu_df["dayOfMonth"].value_counts(normalize=True).sort_index()
axes.bar(data.index, data, color='pink', width=0.5, zorder=0)
axes.plot(data.index, data, color='red', zorder=1)
axes.scatter(data.index, data, s=50, color='darkred', zorder=2)

axes.set_xlabel('Date of Month')
axes.set_xticks(np.arange(1, 32))
axes.set_xticklabels([str(val) for val in np.arange(1, 32)])
axes.set_ylim(0, 0.1)
axes.set_title('% of Neutral tweets by Date of Month')

plt.show()

# %%
df["year"] = df.timestamp.dt.year
df_2019=df[df.year==2019]
df_2020=df[df.year==2020]
df
# Out:
#                                                    text  \
# 0     Here it is a full link of Nerpada pesu @PTTVOn...
# 1     • Guys, here is the tag  #SuriyaFCWarnsBJPnADM...
# 2     @karthickselvaa hope will discuss about this p...
# 3     Speak a few words friendly to Meera during her...
# 4     What were you doing at MCdonlad ? Lootay huy p...
# 10                                     Thank you pesu!!
# 11        Type nerpada pesu at you tube its available..
# 12    Just type nerpada pesu at youtube you will get...
# 13    Dai arivu ketta pu... don't you have sense... ...
# 14    Looks like the news channels are running out o...
# 20    I found this awesome recording of "Kanmaniye P...
# 21    First onnu olunga pesu.. selling price 80 cr n...
# 22    C'mon mchn pesu Amma ..appa ..uncle.... aunty ...
# 23     Po da publicity paithiyam first respect aaa pesu
# 24    I am all for freedom of expression why does on...
# 30    Humble request to @mkstalin @arivalayam hereaf...
# 31    your father mr sarathkumar how he abused veter...
# 32    I love everyone who has "TRUTH EMBARGO" on the...
# 33    Mairu Jan 10 ungu ponagala vivegam kuda workin...
# 38    Mariyathaya pesu. I never used any abusive lan...
# 39    Mariyathaiah pesu, Atleast she's from Tamilnad...
# 40    Punda kalapa worldwide gross paththi pesu da p...
# 41    First know about top order and middle order st...
# 42    Potta bairavaa had a delayed release in 200 sc...
# 43                 SRM SUICIED pathi nee pesu first ...
# 44    Dai Yuvi records beat panitu vanthu pesu Da fi...
# 45    A vision many tamils had a thirst like feeling...
# 54    People should definitely boycott @PTTVOnlineNe...
# 55                        What you can’t ? Pesu da pesu
# 56    En kitta pesu pls pls pls pls pls pls pls pls ...
# ...                                                 ...
# 1795  Webinar - Reboot to Recruit\n\nJob opportuniti...
# 1798  PES university has announced its online entran...
# 1799  #Direct admission in @PES UNIVERSITY\n@Admissi...
# 1800  Online Workshop on setting up e-commerce store...
# 1804  This past weekend, our COO Harsha Chaturvedi h...
# 1805  RT Amul_Coop: Join #Amul Facebook Live at 7 pm...
# 1806  Join #Amul Facebook Live at 7 pm today for #Si...
# 1807  Prof M R Doreswamy, Chancellor, PES University...
# 1812  PES University | Ranking | Courses | Fee | Adm...
# 1813  All the Technical clubs of PES University - EC...
# 1814  The Technical Clubs and Student Chapters at PE...
# 1818  @CMofKarnataka @PESUniversity I hope The gover...
# 1819  @PESUniversity My sister is studying in your l...
# 1820  *#PES UNIVERSITY*\n#Direct admission in PES #U...
# 1821  WarrenBuffett Hello sir,\nI'm Raiba Bhosale, m...
# 1822  @WarrenBuffett Hello sir,\nI'm Raiba Bhosale, ...
# 1823  Clefhangers team win at city’s techno-cultural...
# 1824  $! PES University#\n@Direct #admission in #PES...
# 1832  PES University Admission 2020: Application (St...
# 1833  PESSAT 2020 Exam – Registration, Dates, Eligib...
# 1834  I shoot people. @ PES University https://www.i...
# 1835  Young innovators from PES University, Bengalur...
# 1840  PES University in the Media: Tech education ca...
# 1841  #PES UNIVERSITY @admission Bangalore 2020\nPES...
# 1842  Management quota Admission in Pes University c...
# 1843  PES University in the Media: Coronavirus a sho...
# 1844  Burning down @PESUniversity pic.twitter.com/Uf...
# 1845  supritha_shivakumar \nchinzz.12 \n\n#enlighten...
# 1846  #Direct admission in @PES UNIVERSITY\n@Admissi...
# 1854  PES University Admission 2020: Application (St...
#
#                           username             tweet_id           timestamp  \
# 0          SURIYA FANS CLUB -SALEM  1150816351470010368 2019-07-15 17:16:13
# 1     ®anjith SF©™✈Soorarai Pottru  1150766936008978432 2019-07-15 13:59:52
# 2              Kanthi Mathi Nathan  1150705572649394176 2019-07-15 09:56:02
# 3                      Kiddy Vijay  1150620271717449728 2019-07-15 04:17:04
# 4                     Sohail Shami  1150102123356610560 2019-07-13 17:58:08
# 10                           erica  1141703346773880832 2019-06-20 13:44:24
# 11            சூர்யா@தமிழ் பிரியன்  1141612062595878912 2019-06-20 07:41:40
# 12            சூர்யா@தமிழ் பிரியன்  1141392402516590592 2019-06-19 17:08:49
# 13                    Riyaz ahamed  1141353308574982144 2019-06-19 14:33:28
# 14               EEEINDHIIYAAAAAAA  1141344705080254464 2019-06-19 13:59:17
# 20                           Vivek  1138851256556957696 2019-06-12 16:51:13
# 21     #Karthik 𝓣𝓱𝓪𝓵𝓪𝓹𝓪𝓽𝓱𝔂𝓥𝓲𝓳𝓪𝔂46👑  1138347089031655424 2019-06-11 07:27:50
# 22                   Pugazh VJ❤️VK  1138329156326838272 2019-06-11 06:16:34
# 23                          Prabha  1138237487652851712 2019-06-11 00:12:19
# 24                The life saffron  1137962475549286400 2019-06-10 05:59:31
# 30                           kanna  1141006209916342272 2019-06-18 15:34:13
# 31                       ravikumar  1140949268812820480 2019-06-18 11:47:58
# 32                      Maria Pesu  1140556727349370880 2019-06-17 09:48:08
# 33                         Valimai  1140097423060004864 2019-06-16 03:23:02
# 38                          Thiaga  1144127894362284032 2019-06-27 06:18:41
# 39                            Naga  1143887510667321344 2019-06-26 14:23:29
# 40                 Prãvèéñ Dhanush  1143822986052374528 2019-06-26 10:07:05
# 41                          vishnu  1143762990279249920 2019-06-26 06:08:41
# 42                     Bĺäčk Đevil  1143497579314855936 2019-06-25 12:34:02
# 43                     Karunanidhi  1143463527761321984 2019-06-25 10:18:44
# 44                       itizkrish  1143426288922681344 2019-06-25 07:50:45
# 45                  Varmaadhiyaman  1143424754604363776 2019-06-25 07:44:39
# 54                    SG Ramadurai  1139859225515966464 2019-06-15 11:36:31
# 55                   Paul Ebenezer  1139726637681926144 2019-06-15 02:49:40
# 56                   Thala veriyan  1139700566777450496 2019-06-15 01:06:04
# ...                            ...                  ...                 ...
# 1795                PES University  1269649505135104000 2020-06-07 15:16:45
# 1798           Horace Edu Research  1266671763867332608 2020-05-30 10:04:16
# 1799              himshekher singh  1266605875088683008 2020-05-30 05:42:27
# 1800                PES University  1266370963139989504 2020-05-29 14:09:00
# 1804                   EOX Vantage  1272591936386408448 2020-06-15 18:08:55
# 1805          कक्का जी कहिन.......  1272365334457180160 2020-06-15 03:08:29
# 1806                     Amul.coop  1272361751586181120 2020-06-15 02:54:15
# 1807                PES University  1272181820373622784 2020-06-14 14:59:16
# 1812   CampusWala EdTech Pvt. Ltd.  1258247699112923136 2020-05-07 04:10:03
# 1813                  Dhruv Bindra  1258058865683369984 2020-05-06 15:39:41
# 1814                     Meet Shah  1258055628389593088 2020-05-06 15:26:50
# 1818                     Meet Shah  1265950558944403456 2020-05-28 10:18:28
# 1819                Chhaya Taparia  1265896210642108416 2020-05-28 06:42:30
# 1820              himshekher singh  1265888325409234944 2020-05-28 06:11:10
# 1821    South Carolina Energy News  1265719421529702400 2020-05-27 19:00:00
# 1822                 Raiba Bhosale  1265719280307298304 2020-05-27 18:59:27
# 1823                PES University  1265656652419588096 2020-05-27 14:50:35
# 1824              himshekher singh  1265175516480368640 2020-05-26 06:58:43
# 1832                       Eduport  1261584038143365120 2020-05-16 09:07:28
# 1833               College Pravesh  1261364490316046336 2020-05-15 18:35:04
# 1834                Sreejith Reddy  1261318949695823872 2020-05-15 15:34:06
# 1835                  Unisys India  1261158214202200064 2020-05-15 04:55:24
# 1840                PES University  1271089308749795328 2020-06-11 14:38:01
# 1841              himshekher singh  1270952638704570368 2020-06-11 05:34:56
# 1842                  surjit kumar  1270689280587776000 2020-06-10 12:08:27
# 1843                PES University  1270367632835833856 2020-06-09 14:50:20
# 1844                            Am  1270274789278511104 2020-06-09 08:41:24
# 1845                           RCP  1270269779853672448 2020-06-09 08:21:30
# 1846              himshekher singh  1270243655865872384 2020-06-09 06:37:42
# 1854                       Eduport  1262247242787848192 2020-05-18 05:02:48
#
#                                                hashtags      screen_name  \
# 0                        ['SuriyaFCWarnsBJPnADMKhttps']   Salem_sfc_offl
# 1                ['SuriyaFCWarnsBJPnADMK', 'Kadamboor']      Ranjith_SFC
# 2                                                    []         kanthi90
# 3                                    ['BiggBossTamil3']       KiddyVijay
# 4                                                    []  engineersohail3
# 10                                                   []      EricaRymndo
# 11                                                   []  Tamilpr69418381
# 12                                                   []  Tamilpr69418381
# 13                                                   []  Riyazah61126399
# 14                                                   []     Ohnomynameis
# 20                                            ['Smule']    Vivek93864694
# 21                                                   []      sacvims1033
# 22                                                   []         pugazh98
# 23                                                   []      Prabhakavi_
# 24                                                   []   thelifesaffron
# 30                                                   []    Kanna05083251
# 31                                                   []      raviathiral
# 32                                                   []       Maria_Pesu
# 33                                                   []   MohanKumarCr71
# 38                                                   []   doubleducker87
# 39                                                   []     vnagapraveen
# 40                                                   []      Praveen_Dna
# 41                                                   []        vichu2518
# 42                                                   []      ajakkumama9
# 43                                                   []         sknidhi7
# 44                                                   []      krishcena25
# 45                                                   []   varmaadhiyaman
# 54                                                   []      RamaduraiSg
# 55                                                   []       paulebe525
# 56                                                   []    dhanush_billa
# ...                                                 ...              ...
# 1795                                                 []    PESUniversity
# 1798                                   ['admissionpic']        HoraceEdu
# 1799  ['Direct', 'UNIVERSITY', 'Admission', 'Admissi...      HimshekherS
# 1800                                                 []    PESUniversity
# 1804                                                 []       eoxvantage
# 1805          ['Amul', 'SimpleHomemadeRecipes', 'Chef']       aloksinghk
# 1806          ['Amul', 'SimpleHomemadeRecipes', 'Chef']        Amul_Coop
# 1807                                                 []    PESUniversity
# 1812                                                 []       CampusWala
# 1813                          ['MSFTStudentPartnerpic']     DhruvBindra4
# 1814                                  ['codeislifepic']     meet19061999
# 1818                                                 []     meet19061999
# 1819                                                 []   chhaya_taparia
# 1820  ['PES', 'Direct', 'UNIVERSITY', 'Admission', '...      HimshekherS
# 1821  ['renewableenergy', 'COVID19', 'cleanenergy', ...         scegnews
# 1822  ['renewableenergy', 'COVID19', 'cleanenergy', ...    bhosale_raiba
# 1823                                                 []    PESUniversity
# 1824           ['admission', 'PES', 'PES', 'Bangalore']      HimshekherS
# 1832                                                 []      Eduportplus
# 1833       ['EntranceExams', 'PESUniversity', 'PESSAT']   CollegePravesh
# 1834                                                 []         _vritra_
# 1835  ['Cloud2020Y11', 'InnovationFest', 'AmazingUni...      UnisysIndia
# 1840                                                 []    PESUniversity
# 1841  ['PES', 'admission', 'management', 'Management...      HimshekherS
# 1842                                                 []  surjitk69266301
# 1843                                                 []    PESUniversity
# 1844                                                 []       amfalsegod
# 1845       ['enlighteninghumanlives', 'thankyouheroes']      rc_pesu3190
# 1846  ['Direct', 'UNIVERSITY', 'Admission', 'PES', '...      HimshekherS
# 1854                                                 []      Eduportplus
#
#       retweets  uni_handle  compound Sentiment monthName    dayName  \
# 0            6         0.0    0.0000   Neutral      July     Monday
# 1           47         0.0   -0.4184  Negative      July     Monday
# 2            0         0.0    0.4404  Positive      July     Monday
# 3            0         0.0    0.9656  Positive      July     Monday
# 4            0         0.0    0.0000   Neutral      July   Saturday
# 10           0         0.0    0.4738  Positive      June   Thursday
# 11           0         0.0    0.0000   Neutral      June   Thursday
# 12           0         0.0    0.0000   Neutral      June  Wednesday
# 13           0         0.0   -0.2824  Negative      June  Wednesday
# 14           0         0.0    0.2003  Positive      June  Wednesday
# 20           0         0.0    0.7073  Positive      June  Wednesday
# 21           0         0.0    0.7870  Positive      June    Tuesday
# 22           0         0.0    0.4215  Positive      June    Tuesday
# 23           0         0.0   -0.1280  Negative      June    Tuesday
# 24           0         0.0    0.8555  Positive      June     Monday
# 30           0         0.0   -0.1685  Negative      June    Tuesday
# 31           0         0.0   -0.1027  Negative      June    Tuesday
# 32           0         0.0    0.8038  Positive      June     Monday
# 33           0         0.0    0.0000   Neutral      June     Sunday
# 38           0         0.0    0.5216  Positive      June   Thursday
# 39           0         0.0   -0.2755  Negative      June  Wednesday
# 40           0         0.0   -0.4767  Negative      June  Wednesday
# 41           0         0.0    0.4939  Positive      June  Wednesday
# 42           0         0.0   -0.1154  Negative      June    Tuesday
# 43           0         0.0    0.0000   Neutral      June    Tuesday
# 44           0         0.0    0.0000   Neutral      June    Tuesday
# 45           0         0.0    0.8957  Positive      June    Tuesday
# 54           0         0.0    0.1027  Positive      June   Saturday
# 55           0         0.0    0.0000   Neutral      June   Saturday
# 56           0         0.0    0.9643  Positive      June   Saturday
# ...        ...         ...       ...       ...       ...        ...
# 1795         0         1.0    0.8519  Positive      June     Sunday
# 1798         0         0.0    0.0000   Neutral       May   Saturday
# 1799         0         0.0    0.0000   Neutral       May   Saturday
# 1800         0         1.0    0.0000   Neutral       May     Friday
# 1804         0         0.0    0.9523  Positive      June     Monday
# 1805         0         0.0    0.5994  Positive      June     Monday
# 1806         1         0.0    0.5994  Positive      June     Monday
# 1807         0         1.0    0.0000   Neutral      June     Sunday
# 1812         0         0.0    0.0000   Neutral       May   Thursday
# 1813         2         0.0    0.0000   Neutral       May  Wednesday
# 1814         1         0.0    0.0000   Neutral       May  Wednesday
# 1818         0         0.0    0.4404  Positive       May   Thursday
# 1819         0         0.0    0.0000   Neutral       May   Thursday
# 1820         0         0.0    0.0000   Neutral       May   Thursday
# 1821         0         0.0    0.7430  Positive       May  Wednesday
# 1822         0         0.0    0.7430  Positive       May  Wednesday
# 1823         0         1.0    0.8176  Positive       May  Wednesday
# 1824         0         0.0    0.0000   Neutral       May    Tuesday
# 1832         0         0.0    0.0000   Neutral       May   Saturday
# 1833         0         0.0    0.0000   Neutral       May     Friday
# 1834         0         0.0   -0.3400  Negative       May     Friday
# 1835         0         0.0    0.8689  Positive       May     Friday
# 1840         0         1.0    0.3818  Positive      June   Thursday
# 1841         0         0.0    0.0000   Neutral      June   Thursday
# 1842         1         0.0    0.0000   Neutral      June  Wednesday
# 1843         0         1.0    0.2732  Positive      June    Tuesday
# 1844         0         0.0    0.0000   Neutral      June    Tuesday
# 1845         0         0.0    0.0000   Neutral      June    Tuesday
# 1846         0         0.0    0.0000   Neutral      June    Tuesday
# 1854         0         0.0    0.0000   Neutral       May     Monday
#
#       dayOfMonth                                       Text_cleaned  \
# 0             15  [full, link, nerpada, pesu, pttvonlinenews, ch...
# 1             15  [, guys, tag, suriyafcwarnsbjpnadmk, every, ci...
# 2             15  [karthickselvaa, hope, discuss, program, namec...
# 3             15  [speak, words, friendly, meera, paris, corner,...
# 4             13  [mcdonlad, lootay, huy, pesu, k, kha, rhay, ho, ]
# 10            20                                      [thank, pesu]
# 11            20             [type, nerpada, pesu, tube, available]
# 12            19                [type, nerpada, pesu, youtube, get]
# 13            19  [dai, arivu, ketta, pu, dont, sense, lower, ca...
# 14            19  [looks, like, news, channels, running, topics,...
# 20            12  [found, awesome, recording, kanmaniye, pesu, m...
# 21            11  [first, onnu, olunga, pesu, selling, price, cr...
# 22            11  [cmon, mchn, pesu, amma, appa, uncle, aunty, s...
# 23            11  [po, da, publicity, paithiyam, first, respect,...
# 24            10  [freedom, expression, one, need, reservations,...
# 30            18  [humble, request, mkstalin, arivalayam, hereaf...
# 31            18  [father, mr, sarathkumar, abused, veteran, sen...
# 32            17              [love, everyone, truth, embargo, bio]
# 33            16  [mairu, jan, ungu, ponagala, vivegam, kuda, wo...
# 38            27  [mariyathaya, pesu, never, used, abusive, lang...
# 39            26  [mariyathaiah, pesu, atleast, shes, tamilnadu,...
# 40            26  [punda, kalapa, worldwide, gross, paththi, pes...
# 41            26  [first, know, top, order, middle, order, stata...
# 42            25  [potta, bairavaa, delayed, release, screens, s...
# 43            25          [srm, suicied, pathi, nee, pesu, first, ]
# 44            25  [dai, yuvi, records, beat, panitu, vanthu, pes...
# 45            25  [vision, many, tamils, thirst, like, feeling, ...
# 54            15  [people, definitely, boycott, pttvonlinenews, ...
# 55            15                                   [pesu, da, pesu]
# 56            15  [en, kitta, pesu, pls, pls, pls, pls, pls, pls...
# ...          ...                                                ...
# 1795           7  [webinar, reboot, recruit, job, opportunities,...
# 1798          30  [pes, university, announced, online, entrance,...
# 1799          30  [direct, admission, pes, university, admission...
# 1800          29  [online, workshop, setting, ecommerce, store, ...
# 1804          15  [past, weekend, coo, harsha, chaturvedi, honor...
# 1805          15  [rt, amulcoop, join, amul, facebook, live, pm,...
# 1806          15  [join, amul, facebook, live, pm, today, simple...
# 1807          14  [prof, r, doreswamy, chancellor, pes, universi...
# 1812           7  [pes, university, ranking, courses, fee, admis...
# 1813           6  [technical, clubs, pes, university, ecc, organ...
# 1814           6  [technical, clubs, student, chapters, pes, uni...
# 1818          28  [cmofkarnataka, pesuniversity, hope, governmen...
# 1819          28  [pesuniversity, sister, studying, law, school,...
# 1820          28  [pes, university, direct, admission, pes, univ...
# 1821          27  [warrenbuffett, hello, sir, im, raiba, bhosale...
# 1822          27  [warrenbuffett, hello, sir, im, raiba, bhosale...
# 1823          27  [clefhangers, team, win, city, technocultural,...
# 1824          26  [, pes, university, direct, admission, pes, un...
# 1832          16  [pes, university, admission, application, star...
# 1833          15  [pessat, exam, registration, dates, eligibilit...
# 1834          15                 [shoot, people, pes, university, ]
# 1835          15  [young, innovators, pes, university, bengaluru...
# 1840          11  [pes, university, media, tech, education, purs...
# 1841          11  [pes, university, admission, bangalore, pes, u...
# 1842          10  [management, quota, admission, pes, university...
# 1843           9  [pes, university, media, coronavirus, shot, ar...
# 1844           9    [burning, pesuniversity, pictwittercomuftlvbpy]
# 1845           9  [suprithashivakumar, chinzz, enlighteninghuman...
# 1846           9  [direct, admission, pes, university, admission...
# 1854          18  [pes, university, admission, application, star...
#
#                                         Text_lemmatized  \
# 0     [full, link, nerpada, pesu, pttvonlinenews, ch...
# 1     [, guy, tag, suriyafcwarnsbjpnadmk, every, cit...
# 2     [karthickselvaa, hope, discus, program, nameca...
# 3     [speak, word, friendly, meera, paris, corner, ...
# 4     [mcdonlad, lootay, huy, pesu, k, kha, rhay, ho, ]
# 10                                        [thank, pesu]
# 11               [type, nerpada, pesu, tube, available]
# 12                  [type, nerpada, pesu, youtube, get]
# 13    [dai, arivu, ketta, pu, dont, sense, lower, ca...
# 14    [look, like, news, channel, running, topic, di...
# 20    [found, awesome, recording, kanmaniye, pesu, m...
# 21    [first, onnu, olunga, pesu, selling, price, cr...
# 22    [cmon, mchn, pesu, amma, appa, uncle, aunty, s...
# 23    [po, da, publicity, paithiyam, first, respect,...
# 24    [freedom, expression, one, need, reservation, ...
# 30    [humble, request, mkstalin, arivalayam, hereaf...
# 31    [father, mr, sarathkumar, abused, veteran, sen...
# 32                [love, everyone, truth, embargo, bio]
# 33    [mairu, jan, ungu, ponagala, vivegam, kuda, wo...
# 38    [mariyathaya, pesu, never, used, abusive, lang...
# 39    [mariyathaiah, pesu, atleast, shes, tamilnadu,...
# 40    [punda, kalapa, worldwide, gross, paththi, pes...
# 41    [first, know, top, order, middle, order, stata...
# 42    [potta, bairavaa, delayed, release, screen, st...
# 43            [srm, suicied, pathi, nee, pesu, first, ]
# 44    [dai, yuvi, record, beat, panitu, vanthu, pesu...
# 45    [vision, many, tamil, thirst, like, feeling, w...
# 54    [people, definitely, boycott, pttvonlinenews, ...
# 55                                     [pesu, da, pesu]
# 56    [en, kitta, pesu, pls, pls, pls, pls, pls, pls...
# ...                                                 ...
# 1795  [webinar, reboot, recruit, job, opportunity, p...
# 1798  [pe, university, announced, online, entrance, ...
# 1799  [direct, admission, pe, university, admission,...
# 1800  [online, workshop, setting, ecommerce, store, ...
# 1804  [past, weekend, coo, harsha, chaturvedi, honor...
# 1805  [rt, amulcoop, join, amul, facebook, live, pm,...
# 1806  [join, amul, facebook, live, pm, today, simple...
# 1807  [prof, r, doreswamy, chancellor, pe, universit...
# 1812  [pe, university, ranking, course, fee, admissi...
# 1813  [technical, club, pe, university, ecc, organiz...
# 1814  [technical, club, student, chapter, pe, univer...
# 1818  [cmofkarnataka, pesuniversity, hope, governmen...
# 1819  [pesuniversity, sister, studying, law, school,...
# 1820  [pe, university, direct, admission, pe, univer...
# 1821  [warrenbuffett, hello, sir, im, raiba, bhosale...
# 1822  [warrenbuffett, hello, sir, im, raiba, bhosale...
# 1823  [clefhangers, team, win, city, technocultural,...
# 1824  [, pe, university, direct, admission, pe, univ...
# 1832  [pe, university, admission, application, start...
# 1833  [pessat, exam, registration, date, eligibility...
# 1834                  [shoot, people, pe, university, ]
# 1835  [young, innovator, pe, university, bengaluru, ...
# 1840  [pe, university, medium, tech, education, purs...
# 1841  [pe, university, admission, bangalore, pe, uni...
# 1842  [management, quota, admission, pe, university,...
# 1843  [pe, university, medium, coronavirus, shot, ar...
# 1844    [burning, pesuniversity, pictwittercomuftlvbpy]
# 1845  [suprithashivakumar, chinzz, enlighteninghuman...
# 1846  [direct, admission, pe, university, admission,...
# 1854  [pe, university, admission, application, start...
#
#                                     Text_lemmatized_str  year
# 0     full link nerpada pesu pttvonlinenews chief su...  2019
# 1      guy tag suriyafcwarnsbjpnadmk every citizen r...  2019
# 2     karthickselvaa hope discus program namecalled ...  2019
# 3     speak word friendly meera paris corner time ge...  2019
# 4               mcdonlad lootay huy pesu k kha rhay ho   2019
# 10                                           thank pesu  2019
# 11                     type nerpada pesu tube available  2019
# 12                        type nerpada pesu youtube get  2019
# 13    dai arivu ketta pu dont sense lower caste peop...  2019
# 14    look like news channel running topic discus ne...  2019
# 20    found awesome recording kanmaniye pesu mounam ...  2019
# 21    first onnu olunga pesu selling price cr na pro...  2019
# 22    cmon mchn pesu amma appa uncle aunty sunny mia...  2019
# 23      po da publicity paithiyam first respect aa pesu  2019
# 24    freedom expression one need reservation freedo...  2019
# 30    humble request mkstalin arivalayam hereafter p...  2019
# 31    father mr sarathkumar abused veteran senior re...  2019
# 32                      love everyone truth embargo bio  2019
# 33    mairu jan ungu ponagala vivegam kuda working d...  2019
# 38         mariyathaya pesu never used abusive language  2019
# 39    mariyathaiah pesu atleast shes tamilnadu pakis...  2019
# 40    punda kalapa worldwide gross paththi pesu da p...  2019
# 41    first know top order middle order statagies co...  2019
# 42    potta bairavaa delayed release screen still co...  2019
# 43                    srm suicied pathi nee pesu first   2019
# 44    dai yuvi record beat panitu vanthu pesu da fir...  2019
# 45    vision many tamil thirst like feeling watching...  2019
# 54    people definitely boycott pttvonlinenews nepad...  2019
# 55                                         pesu da pesu  2019
# 56    en kitta pesu pls pls pls pls pls pls pls pls ...  2019
# ...                                                 ...   ...
# 1795  webinar reboot recruit job opportunity post pa...  2020
# 1798  pe university announced online entrance exam a...  2020
# 1799  direct admission pe university admission pe un...  2020
# 1800  online workshop setting ecommerce store studen...  2020
# 1804  past weekend coo harsha chaturvedi honor judgi...  2020
# 1805  rt amulcoop join amul facebook live pm today s...  2020
# 1806  join amul facebook live pm today simplehomemad...  2020
# 1807  prof r doreswamy chancellor pe university advi...  2020
# 1812  pe university ranking course fee admission hos...  2020
# 1813  technical club pe university ecc organizing ai...  2020
# 1814  technical club student chapter pe university e...  2020
# 1818  cmofkarnataka pesuniversity hope government go...  2020
# 1819  pesuniversity sister studying law school recei...  2020
# 1820  pe university direct admission pe university d...  2020
# 1821  warrenbuffett hello sir im raiba bhosale mecha...  2020
# 1822  warrenbuffett hello sir im raiba bhosale mecha...  2020
# 1823  clefhangers team win city technocultural fest ...  2020
# 1824   pe university direct admission pe university ...  2020
# 1832  pe university admission application started el...  2020
# 1833  pessat exam registration date eligibility fee ...  2020
# 1834                        shoot people pe university   2020
# 1835  young innovator pe university bengaluru presen...  2020
# 1840  pe university medium tech education pursue new...  2020
# 1841  pe university admission bangalore pe universit...  2020
# 1842  management quota admission pe university call ...  2020
# 1843  pe university medium coronavirus shot arm biot...  2020
# 1844        burning pesuniversity pictwittercomuftlvbpy  2020
# 1845  suprithashivakumar chinzz enlighteninghumanliv...  2020
# 1846  direct admission pe university admission pe un...  2020
# 1854  pe university admission application started el...  2020
#
# [935 rows x 17 columns]

# %%
fig, axes = plt.subplots(figsize=(15,6))

data = df_2019["dayOfMonth"].value_counts(normalize=True).sort_index()
axes.bar(data.index, data, color='pink', width=0.5, zorder=0)
axes.plot(data.index, data, color='red', zorder=1)
axes.scatter(data.index, data, s=50, color='darkred', zorder=2)

axes.set_xlabel('Date of Month')
axes.set_xticks(np.arange(1, 32))
axes.set_xticklabels([str(val) for val in np.arange(1, 32)])
axes.set_ylim(0, 0.1)
axes.set_title('% of tweets by Date of Month for Academic session Jun-Dec 2019')

plt.show()

# %%
fig, axes = plt.subplots(figsize=(15,6))

data = df_2020["dayOfMonth"].value_counts(normalize=True).sort_index()
axes.bar(data.index, data, color='pink', width=0.5, zorder=0)
axes.plot(data.index, data, color='red', zorder=1)
axes.scatter(data.index, data, s=50, color='darkred', zorder=2)

axes.set_xlabel('Date of Month')
axes.set_xticks(np.arange(1, 32))
axes.set_xticklabels([str(val) for val in np.arange(1, 32)])
axes.set_ylim(0, 0.1)
axes.set_title('% of tweets by Date of Month for Academic session Jan-June 2020')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
pos_2019 = df_2019[df_2019.Sentiment == 'Positive']
data = pos_2019["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of pos tweets by month in Jun-Dec 2019')

data = pos_2019["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of pos tweets by week Jun-Dec 2019')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
neg_2019 = df_2019[df_2019.Sentiment == 'Negative']
data = neg_2019["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of neg tweets by month in Jun-Dec 2019')

data = neg_2019["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of neg tweets by week Jun-Dec 2019')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
neu_2019 = df_2019[df_2019.Sentiment == 'Neutral']
data = neu_2019["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of Neu tweets by month in Jun-Dec 2019')

data = neu_2019["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of pos tweets by week Jun-Dec 2019')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
pos_2020 = df_2020[df_2020.Sentiment == 'Positive']
data = pos_2020["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of pos tweets by month in Jan-Jun 2020')

data = pos_2020["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of pos tweets by week Jan-Jun 2020')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
neg_2020 = df_2020[df_2020.Sentiment == 'Negative']
data = neg_2020["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of neg tweets by month in Jan-Jun 2020')

data = neg_2020["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of neg tweets by week Jan-Jun 2020')

plt.show()

# %%
fig, [axes1, axes2] = plt.subplots(1, 2, figsize=(15,6), sharey=True)
neu_2020 = df_2020[df_2020.Sentiment == 'Neutral']
data = neu_2020["monthName"].value_counts(normalize=True)

axes1.bar(data.index, data*100, color=my_colors)
axes1.set_xticklabels(data.index, rotation=90)
axes1.set_ylabel('Percentage')
axes1.set_title('% of Neu tweets by month in Jan-Jun 2020')

data = neu_2020["dayName"].value_counts(normalize=True)
axes2.bar(data.index, data*100, color=my_colors)
axes2.set_xticklabels(data.index, rotation=90)
axes2.set_title('% of Neu tweets by week Jan-Jun 2019')

plt.show()

# %%
wordfreq = {}
for sentence in df['Text_lemmatized_str']:
    tokens = nltk.word_tokenize(sentence)
    for token in tokens:
        if token not in wordfreq.keys():
            wordfreq[token] = 1
        else:
            wordfreq[token] += 1

# %%
import operator
sorted_wordfreq=sorted(wordfreq.items(),key=operator.itemgetter(1),reverse=True)
sorted_wordfreq
# Out:
# [('pesu', 418),
#  ('pe', 395),
#  ('university', 373),
#  ('admission', 137),
#  ('student', 127),
#  ('pesuniversity', 126),
#  ('u', 97),
#  ('bangalore', 75),
#  ('pls', 67),
#  ('like', 64),
#  ('day', 60),
#  ('th', 59),
#  ('program', 57),
#  ('first', 55),
#  ('india', 49),
#  ('engineering', 48),
#  ('time', 46),
#  ('r', 46),
#  ('college', 46),
#  ('team', 45),
#  ('campus', 45),
#  ('sir', 43),
#  ('direct', 43),
#  ('learning', 43),
#  ('one', 42),
#  ('year', 42),
#  ('bengaluru', 42),
#  ('da', 40),
#  ('dont', 38),
#  ('great', 38),
#  ('held', 38),
#  ('know', 36),
#  ('nee', 36),
#  ('education', 36),
#  ('workshop', 36),
#  ('people', 35),
#  ('biggbosstamil', 35),
#  ('nerpada', 34),
#  ('talk', 34),
#  ('management', 34),
#  ('event', 33),
#  ('today', 32),
#  ('opportunity', 32),
#  ('go', 30),
#  ('kavin', 30),
#  ('member', 29),
#  ('new', 29),
#  ('dr', 28),
#  ('faculty', 28),
#  ('good', 27),
#  ('call', 27),
#  ('science', 27),
#  ('also', 26),
#  ('n', 26),
#  ('last', 26),
#  ('law', 25),
#  ('la', 25),
#  ('open', 25),
#  ('get', 24),
#  ('nu', 24),
#  ('indian', 24),
#  ('make', 24),
#  ('cheran', 24),
#  ('website', 24),
#  ('application', 24),
#  ('got', 23),
#  ('road', 23),
#  ('pessat', 23),
#  ('please', 22),
#  ('tamil', 22),
#  ('see', 22),
#  ('would', 22),
#  ('course', 22),
#  ('started', 22),
#  ('data', 22),
#  ('solution', 22),
#  ('machine', 21),
#  ('speak', 20),
#  ('na', 20),
#  ('need', 20),
#  ('pathi', 20),
#  ('many', 20),
#  ('issue', 20),
#  ('work', 20),
#  ('want', 20),
#  ('company', 20),
#  ('karnataka', 20),
#  ('look', 19),
#  ('news', 19),
#  ('industry', 19),
#  ('ah', 19),
#  ('director', 19),
#  ('losliya', 19),
#  ('research', 19),
#  ('well', 19),
#  ('online', 19),
#  ('quota', 19),
#  ('show', 18),
#  ('support', 18),
#  ('pm', 18),
#  ('school', 18),
#  ('winner', 18),
#  ('quiz', 18),
#  ('part', 18),
#  ('family', 18),
#  ('best', 17),
#  ('fan', 17),
#  ('ur', 17),
#  ('top', 17),
#  ('give', 17),
#  ('ne', 17),
#  ('said', 17),
#  ('technology', 17),
#  ('alumnus', 17),
#  ('exam', 17),
#  ('aatmatrisha', 17),
#  ('right', 16),
#  ('movie', 16),
#  ('life', 16),
#  ('doreswamy', 16),
#  ('department', 16),
#  ('detail', 16),
#  ('k', 15),
#  ('vijay', 15),
#  ('record', 15),
#  ('session', 15),
#  ('world', 15),
#  ('much', 15),
#  ('class', 15),
#  ('poi', 15),
#  ('back', 15),
#  ('change', 15),
#  ('help', 15),
#  ('project', 15),
#  ('national', 15),
#  ('via', 15),
#  ('prize', 15),
#  ('traffic', 15),
#  ('launch', 15),
#  ('mba', 15),
#  ('mtech', 15),
#  ('karthickselvaa', 14),
#  ('cr', 14),
#  ('love', 14),
#  ('release', 14),
#  ('song', 14),
#  ('watch', 14),
#  ('say', 14),
#  ('thanks', 14),
#  ('im', 14),
#  ('performance', 14),
#  ('meet', 14),
#  ('organised', 14),
#  ('awesome', 13),
#  ('vanthu', 13),
#  ('happy', 13),
#  ('may', 13),
#  ('ok', 13),
#  ('government', 13),
#  ('bro', 13),
#  ('c', 13),
#  ('thats', 13),
#  ('hindi', 13),
#  ('oru', 13),
#  ('around', 13),
#  ('study', 13),
#  ('always', 13),
#  ('system', 13),
#  ('going', 13),
#  ('win', 13),
#  ('hackathon', 13),
#  ('international', 13),
#  ('invited', 13),
#  ('covid', 13),
#  ('full', 12),
#  ('pttvonlinenews', 12),
#  ('question', 12),
#  ('hope', 12),
#  ('word', 12),
#  ('fight', 12),
#  ('take', 12),
#  ('respect', 12),
#  ('mr', 12),
#  ('still', 12),
#  ('saw', 12),
#  ('water', 12),
#  ('use', 12),
#  ('tweet', 12),
#  ('nd', 12),
#  ('vanitha', 12),
#  ('rd', 12),
#  ('based', 12),
#  ('contest', 12),
#  ('place', 12),
#  ('registration', 12),
#  ('chancellor', 12),
#  ('prof', 12),
#  ('mechanical', 12),
#  ('institute', 12),
#  ('hospitality', 12),
#  ('llb', 12),
#  ('spend', 12),
#  ('guy', 11),
#  ('every', 11),
#  ('medium', 11),
#  ('ழ', 11),
#  ('never', 11),
#  ('real', 11),
#  ('check', 11),
#  ('man', 11),
#  ('energy', 11),
#  ('come', 11),
#  ('let', 11),
#  ('govt', 11),
#  ('illa', 11),
#  ('bring', 11),
#  ('st', 11),
#  ('conduct', 11),
#  ('point', 11),
#  ('video', 11),
#  ('tour', 11),
#  ('social', 11),
#  ('congratulation', 11),
#  ('house', 11),
#  ('tech', 11),
#  ('sport', 11),
#  ('conducted', 11),
#  ('paper', 11),
#  ('experience', 11),
#  ('amazing', 11),
#  ('final', 11),
#  ('visit', 11),
#  ('city', 11),
#  ('development', 11),
#  ('club', 11),
#  ('form', 11),
#  ('career', 11),
#  ('contact', 11),
#  ('friend', 10),
#  ('kitta', 10),
#  ('beat', 10),
#  ('waste', 10),
#  ('hour', 10),
#  ('sri', 10),
#  ('country', 10),
#  ('others', 10),
#  ('even', 10),
#  ('tell', 10),
#  ('way', 10),
#  ('start', 10),
#  ('dei', 10),
#  ('participant', 10),
#  ('hey', 10),
#  ('speaker', 10),
#  ('cricket', 10),
#  ('b', 10),
#  ('second', 10),
#  ('sherin', 10),
#  ('job', 10),
#  ('institution', 10),
#  ('quality', 10),
#  ('award', 10),
#  ('organized', 10),
#  ('justice', 10),
#  ('article', 10),
#  ('eligibility', 10),
#  ('stay', 10),
#  ('staff', 10),
#  ('guidance', 10),
#  ('fee', 10),
#  ('reform', 10),
#  ('debate', 9),
#  ('ippo', 9),
#  ('twitter', 9),
#  ('mattum', 9),
#  ('among', 9),
#  ('using', 9),
#  ('summa', 9),
#  ('think', 9),
#  ('ppl', 9),
#  ('thing', 9),
#  ('speaking', 9),
#  ('yesterday', 9),
#  ('star', 9),
#  ('abt', 9),
#  ('talking', 9),
#  ('idea', 9),
#  ('woman', 9),
#  ('p', 9),
#  ('discussion', 9),
#  ('innovative', 9),
#  ('join', 9),
#  ('business', 9),
#  ('seminar', 9),
#  ('ring', 9),
#  ('semester', 9),
#  ('vehicle', 9),
#  ('nov', 9),
#  ('festival', 9),
#  ('ankit', 9),
#  ('initiative', 9),
#  ('model', 9),
#  ('mayur', 9),
#  ('doesnt', 8),
#  ('type', 8),
#  ('youtube', 8),
#  ('topic', 8),
#  ('working', 8),
#  ('tha', 8),
#  ('pa', 8),
#  ('tournament', 8),
#  ('pathu', 8),
#  ('attend', 8),
#  ('info', 8),
#  ('post', 8),
#  ('party', 8),
#  ('thambi', 8),
#  ('mean', 8),
#  ('told', 8),
#  ('try', 8),
#  ('lakh', 8),
#  ('learn', 8),
#  ('care', 8),
#  ('live', 8),
#  ('music', 8),
#  ('stop', 8),
#  ('next', 8),
#  ('collection', 8),
#  ('didnt', 8),
#  ('stupid', 8),
#  ('fact', 8),
#  ('oda', 8),
#  ('building', 8),
#  ('trying', 8),
#  ('lot', 8),
#  ('un', 8),
#  ('home', 8),
#  ('army', 8),
#  ('fake', 8),
#  ('making', 8),
#  ('expert', 8),
#  ('front', 8),
#  ('offer', 8),
#  ('design', 8),
#  ('mom', 8),
#  ('week', 8),
#  ('ai', 8),
#  ('rt', 8),
#  ('guest', 8),
#  ('annual', 8),
#  ('edition', 8),
#  ('professor', 8),
#  ('batch', 8),
#  ('startup', 8),
#  ('must', 8),
#  ('october', 8),
#  ('date', 8),
#  ('pesuopenhouse', 8),
#  ('march', 8),
#  ('advisor', 8),
#  ('trump', 8),
#  ('iso', 8),
#  ('certified', 8),
#  ('mishra', 8),
#  ('ani', 8),
#  ('gautam', 8),
#  ('shekhar', 8),
#  ('discus', 7),
#  ('amma', 7),
#  ('channel', 7),
#  ('found', 7),
#  ('recording', 7),
#  ('தம', 7),
#  ('smule', 7),
#  ('huge', 7),
#  ('everyone', 7),
#  ('jan', 7),
#  ('used', 7),
#  ('language', 7),
#  ('proud', 7),
#  ('super', 7),
#  ('kita', 7),
#  ('reply', 7),
#  ('update', 7),
#  ('ajith', 7),
#  ('game', 7),
#  ('sign', 7),
#  ('software', 7),
#  ('highest', 7),
#  ('virus', 7),
#  ('information', 7),
#  ('reach', 7),
#  ('comedy', 7),
#  ('police', 7),
#  ('everything', 7),
#  ('become', 7),
#  ('community', 7),
#  ('high', 7),
#  ('lawyer', 7),
#  ('bb', 7),
#  ('made', 7),
#  ('professional', 7),
#  ('put', 7),
#  ('vote', 7),
#  ('problem', 7),
#  ('ila', 7),
#  ('called', 7),
#  ('kashmir', 7),
#  ('panel', 7),
#  ('app', 7),
#  ('chapter', 7),
#  ('group', 7),
#  ('yes', 7),
#  ('side', 7),
#  ('hello', 7),
#  ('president', 7),
#  ('took', 7),
#  ('november', 7),
#  ('inaugurated', 7),
#  ('across', 7),
#  ('child', 7),
#  ('v', 7),
#  ('mca', 7),
#  ('near', 7),
#  ('fest', 7),
#  ('skill', 7),
#  ('important', 7),
#  ('championship', 7),
#  ('hotel', 7),
#  ('challenge', 7),
#  ('technical', 7),
#  ('society', 7),
#  ('feb', 7),
#  ('various', 7),
#  ('february', 7),
#  ('thank', 6),
#  ('kanmaniye', 6),
#  ('ku', 6),
#  ('request', 6),
#  ('father', 6),
#  ('punda', 6),
#  ('programme', 6),
#  ('en', 6),
#  ('album', 6),
#  ('integrated', 6),
#  ('speech', 6),
#  ('level', 6),
#  ('seen', 6),
#  ('த', 6),
#  ('wish', 6),
#  ('ever', 6),
#  ('block', 6),
#  ('july', 6),
#  ('konjam', 6),
#  ('matter', 6),
#  ('los', 6),
#  ('giving', 6),
#  ('tn', 6),
#  ('kamal', 6),
#  ('interview', 6),
#  ('nice', 6),
#  ('bad', 6),
#  ('asking', 6),
#  ('another', 6),
#  ('million', 6),
#  ('register', 6),
#  ('pannu', 6),
#  ('difference', 6),
#  ('report', 6),
#  ('taken', 6),
#  ('men', 6),
#  ('over', 6),
#  ('baby', 6),
#  ('special', 6),
#  ('state', 6),
#  ('role', 6),
#  ('submission', 6),
#  ('wrong', 6),
#  ('saying', 6),
#  ('ava', 6),
#  ('future', 6),
#  ('dance', 6),
#  ('evlo', 6),
#  ('really', 6),
#  ('dsc', 6),
#  ('cloud', 6),
#  ('money', 6),
#  ('current', 6),
#  ('fun', 6),
#  ('kannada', 6),
#  ('south', 6),
#  ('small', 6),
#  ('ceremony', 6),
#  ('electric', 6),
#  ('range', 6),
#  ('process', 6),
#  ('test', 6),
#  ('outside', 6),
#  ('service', 6),
#  ('hosted', 6),
#  ('fourth', 6),
#  ('educational', 6),
#  ('situation', 6),
#  ('bag', 6),
#  ('build', 6),
#  ('delhi', 6),
#  ('cultural', 6),
#  ('private', 6),
#  ('bba', 6),
#  ('round', 6),
#  ('ರ', 6),
#  ('electronics', 6),
#  ('promote', 6),
#  ('hosur', 6),
#  ('food', 6),
#  ('structure', 6),
#  ('tatacrucible', 6),
#  ('tourism', 6),
#  ('comptia', 6),
#  ('competition', 6),
#  ('graduate', 6),
#  ('ranking', 6),
#  ('enlighteninghumanlives', 6),
#  ('raiba', 6),
#  ('bhosale', 6),
#  ('renewable', 6),
#  ('hybrid', 6),
#  ('link', 5),
#  ('chief', 5),
#  ('tag', 5),
#  ('dai', 5),
#  ('create', 5),
#  ('kind', 5),
#  ('mounam', 5),
#  ('po', 5),
#  ('tv', 5),
#  ('brought', 5),
#  ('kuda', 5),
#  ('result', 5),
#  ('name', 5),
#  ('without', 5),
#  ('dmk', 5),
#  ('reason', 5),
#  ('yen', 5),
#  ('ha', 5),
#  ('sonna', 5),
#  ('ellam', 5),
#  ('scene', 5),
#  ('thala', 5),
#  ('inga', 5),
#  ('paathutu', 5),
#  ('bigil', 5),
#  ('apram', 5),
#  ('recent', 5),
#  ('ask', 5),
#  ('true', 5),
#  ('clear', 5),
#  ('le', 5),
#  ('car', 5),
#  ('together', 5),
#  ('lecture', 5),
#  ('white', 5),
#  ('anna', 5),
#  ('viswasam', 5),
#  ('sollu', 5),
#  ('whatever', 5),
#  ('normal', 5),
#  ('vandhu', 5),
#  ('personal', 5),
#  ('felt', 5),
#  ('ya', 5),
#  ('understanding', 5),
#  ('pannitu', 5),
#  ('mass', 5),
#  ('face', 5),
#  ('global', 5),
#  ('collaboration', 5),
#  ('miss', 5),
#  ('webinar', 5),
#  ('thinking', 5),
#  ('prove', 5),
#  ('unaku', 5),
#  ('film', 5),
#  ('released', 5),
#  ('understand', 5),
#  ('run', 5),
#  ('teach', 5),
#  ('logic', 5),
#  ('tamila', 5),
#  ('light', 5),
#  ('something', 5),
#  ('trend', 5),
#  ('ithu', 5),
#  ('past', 5),
#  ('wont', 5),
#  ('till', 5),
#  ('sarkar', 5),
#  ('enna', 5),
#  ('jam', 5),
#  ('anushka', 5),
#  ('acting', 5),
#  ('sandy', 5),
#  ('ய', 5),
#  ('crore', 5),
#  ('third', 5),
#  ('story', 5),
#  ('save', 5),
#  ('photo', 5),
#  ('office', 5),
#  ('inside', 5),
#  ('insight', 5),
#  ('participated', 5),
#  ('due', 5),
#  ('foam', 5),
#  ('ecc', 5),
#  ('celebration', 5),
#  ('august', 5),
#  ('casual', 5),
#  ('read', 5),
#  ('w', 5),
#  ('including', 5),
#  ('sure', 5),
#  ('artist', 5),
#  ('announced', 5),
#  ('decent', 5),
#  ('tata', 5),
#  ('overall', 5),
#  ('shri', 5),
#  ('court', 5),
#  ('focused', 5),
#  ('electronic', 5),
#  ('area', 5),
#  ('wide', 5),
#  ('conference', 5),
#  ('end', 5),
#  ('association', 5),
#  ('nokia', 5),
#  ('participation', 5),
#  ('fill', 5),
#  ('btech', 5),
#  ('mahatma', 5),
#  ('clinical', 5),
#  ('health', 5),
#  ('shared', 5),
#  ('pesit', 5),
#  ('ಕ', 5),
#  ('young', 5),
#  ('ground', 5),
#  ('celebrating', 5),
#  ('secured', 5),
#  ('ba', 5),
#  ('along', 5),
#  ('january', 5),
#  ('set', 5),
#  ('medal', 5),
#  ('bennydayal', 5),
#  ('thankyouheroes', 5),
#  ('rich', 5),
#  ('citizen', 4),
#  ('paathu', 4),
#  ('available', 4),
#  ('aware', 4),
#  ('advantage', 4),
#  ('hq', 4),
#  ('profit', 4),
#  ('share', 4),
#  ('freedom', 4),
#  ('keep', 4),
#  ('senior', 4),
#  ('actor', 4),
#  ('iruntha', 4),
#  ('history', 4),
#  ('atleast', 4),
#  ('gross', 4),
#  ('paththi', 4),
#  ('potta', 4),
#  ('screen', 4),
#  ('vision', 4),
#  ('watching', 4),
#  ('crisis', 4),
#  ('designed', 4),
#  ('graduating', 4),
#  ('legal', 4),
#  ('vera', 4),
#  ('entry', 4),
#  ('favourite', 4),
#  ('episode', 4),
#  ('ada', 4),
#  ('list', 4),
#  ('ம', 4),
#  ('came', 4),
#  ('english', 4),
#  ('paru', 4),
#  ('coach', 4),
#  ('moment', 4),
#  ('arunrajakamaraj', 4),
#  ('thought', 4),
#  ('mohan', 4),
#  ('mouth', 4),
#  ('contestant', 4),
#  ('bjp', 4),
#  ('supporting', 4),
#  ('control', 4),
#  ('sakshi', 4),
#  ('agreed', 4),
#  ('rather', 4),
#  ('mugen', 4),
#  ('case', 4),
#  ('might', 4),
#  ('subject', 4),
#  ('voice', 4),
#  ('compensation', 4),
#  ('talent', 4),
#  ('ŧ', 4),
#  ('biotech', 4),
#  ('strategy', 4),
#  ('beyond', 4),
#  ('polyethersulfone', 4),
#  ('june', 4),
#  ('account', 4),
#  ('mind', 4),
#  ('panna', 4),
#  ('thaan', 4),
#  ('panni', 4),
#  ('knowledge', 4),
#  ('can', 4),
#  ('not', 4),
#  ('rhy', 4),
#  ('pr', 4),
#  ('play', 4),
#  ('intelindia', 4),
#  ('anything', 4),
#  ('close', 4),
#  ('mari', 4),
#  ('per', 4),
#  ('hate', 4),
#  ('atha', 4),
#  ('bigg', 4),
#  ('lol', 4),
#  ('pesitu', 4),
#  ('though', 4),
#  ('poyi', 4),
#  ('success', 4),
#  ('google', 4),
#  ('va', 4),
#  ('cat', 4),
#  ('power', 4),
#  ('etc', 4),
#  ('வ', 4),
#  ('க', 4),
#  ('free', 4),
#  ('pesa', 4),
#  ('paid', 4),
#  ('could', 4),
#  ('seems', 4),
#  ('arm', 4),
#  ('review', 4),
#  ('construction', 4),
#  ('featured', 4),
#  ('accept', 4),
#  ('person', 4),
#  ('avar', 4),
#  ('iruka', 4),
#  ('generation', 4),
#  ('action', 4),
#  ('policy', 4),
#  ('hero', 4),
#  ('muslim', 4),
#  ('kindly', 4),
#  ('away', 4),
#  ('chennai', 4),
#  ('acmpesu', 4),
#  ('asked', 4),
#  ('frnd', 4),
#  ('sari', 4),
#  ('avan', 4),
#  ('appreciate', 4),
#  ('long', 4),
#  ('manavar', 4),
#  ('mulakkam', 4),
#  ('astro', 4),
#  ('locally', 4),
#  ('security', 4),
#  ('engineer', 4),
#  ('nominated', 4),
#  ('worth', 4),
#  ('present', 4),
#  ('ன', 4),
#  ('nallathey', 4),
#  ('bank', 4),
#  ('whats', 4),
#  ('provide', 4),
#  ('haha', 4),
#  ('daily', 4),
#  ('happiness', 4),
#  ('criminal', 4),
#  ('millennium', 4),
#  ('vocal', 4),
#  ('plant', 4),
#  ('ft', 4),
#  ('daiwik', 4),
#  ('standard', 4),
#  ('received', 4),
#  ('latest', 4),
#  ('occasion', 4),
#  ('volunteer', 4),
#  ('celebrated', 4),
#  ('infini', 4),
#  ('lanka', 4),
#  ('welcome', 4),
#  ('blrcitytraffic', 4),
#  ('flag', 4),
#  ('preetham', 4),
#  ('akhil', 4),
#  ('ensuring', 4),
#  ('safety', 4),
#  ('situated', 4),
#  ('bm', 4),
#  ('vice', 4),
#  ('apply', 4),
#  ('gandhi', 4),
#  ('partner', 4),
#  ('finalist', 4),
#  ('visited', 4),
#  ('son', 4),
#  ('space', 4),
#  ('master', 4),
#  ('cmofkarnataka', 4),
#  ('filled', 4),
#  ('badminton', 4),
#  ('runner', 4),
#  ('kumar', 4),
#  ('vijaykarnataka', 4),
#  ('ನ', 4),
#  ('ಸ', 4),
#  ('sponsor', 4),
#  ('tuned', 4),
#  ('ingenius', 4),
#  ('enthusiast', 4),
#  ('brings', 4),
#  ('internship', 4),
#  ('minister', 4),
#  ('central', 4),
#  ('library', 4),
#  ('pharmacy', 4),
#  ('assistant', 4),
#  ('credit', 4),
#  ('tutorial', 4),
#  ('vpsecretariat', 4),
#  ('vibrant', 4),
#  ('aero', 4),
#  ('confer', 4),
#  ('trainer', 4),
#  ('ceo', 4),
#  ('bsybjp', 4),
#  ('gaming', 4),
#  ('emerged', 4),
#  ('importance', 4),
#  ('m', 4),
#  ('congrats', 4),
#  ('academic', 4),
#  ('hand', 4),
#  ('suryoday', 4),
#  ('pro', 4),
#  ('april', 4),
#  ('presented', 4),
#  ('represented', 4),
#  ('writing', 4),
#  ('entrance', 4),
#  ('doctor', 4),
#  ('pandemic', 4),
#  ('wgsha', 4),
#  ('permission', 4),
#  ('chef', 4),
#  ('sivaram', 4),
#  ('friendly', 3),
#  ('meera', 3),
#  ('two', 3),
#  ('friendship', 3),
#  ('ho', 3),
#  ('mariyathaya', 3),
#  ('cancelled', 3),
#  ('price', 3),
#  ('theatre', 3),
#  ('basis', 3),
#  ('ready', 3),
#  ('buy', 3),
#  ('appa', 3),
#  ('publicity', 3),
#  ('aa', 3),
#  ('reservation', 3),
#  ('send', 3),
#  ('sitting', 3),
#  ('aprm', 3),
#  ('shes', 3),
#  ('worldwide', 3),
#  ('comparing', 3),
#  ('compare', 3),
#  ('collected', 3),
#  ('singam', 3),
#  ('opening', 3),
#  ('multiple', 3),
#  ('feeling', 3),
#  ('big', 3),
#  ('birth', 3),
#  ('given', 3),
#  ('completely', 3),
#  ('regarding', 3),
#  ('girl', 3),
#  ('id', 3),
#  ('playlist', 3),
#  ('fiveyear', 3),
#  ('bballb', 3),
#  ('edge', 3),
#  ('challenging', 3),
#  ('intricate', 3),
#  ('interdisciplinary', 3),
#  ('maari', 3),
#  ('gave', 3),
#  ('hw', 3),
#  ('picture', 3),
#  ('என', 3),
#  ('nanba', 3),
#  ('athu', 3),
#  ('brother', 3),
#  ('intha', 3),
#  ('human', 3),
#  ('shit', 3),
#  ('count', 3),
#  ('mention', 3),
#  ('damn', 3),
#  ('land', 3),
#  ('wall', 3),
#  ('spoke', 3),
#  ('entire', 3),
#  ('yosichi', 3),
#  ('ipdi', 3),
#  ('nelson', 3),
#  ('coming', 3),
#  ('sivakartikeyan', 3),
#  ('attention', 3),
#  ('supported', 3),
#  ('nalla', 3),
#  ('night', 3),
#  ('avala', 3),
#  ('silent', 3),
#  ('ji', 3),
#  ('ka', 3),
#  ('biggest', 3),
#  ('neet', 3),
#  ('assembly', 3),
#  ('discussed', 3),
#  ('easily', 3),
#  ('comment', 3),
#  ('interested', 3),
#  ('bye', 3),
#  ('se', 3),
#  ('healthy', 3),
#  ('jeichittu', 3),
#  ('btw', 3),
#  ('wait', 3),
#  ('instead', 3),
#  ('tharshan', 3),
#  ('pannatha', 3),
#  ('theliva', 3),
#  ('showed', 3),
#  ('hair', 3),
#  ('content', 3),
#  ('die', 3),
#  ('anyone', 3),
#  ('died', 3),
#  ('jackpot', 3),
#  ('energetic', 3),
#  ('exclusive', 3),
#  ('sartorius', 3),
#  ('stedim', 3),
#  ('validation', 3),
#  ('operational', 3),
#  ('practice', 3),
#  ('surface', 3),
#  ('modified', 3),
#  ('filter', 3),
#  ('message', 3),
#  ('chat', 3),
#  ('simple', 3),
#  ('done', 3),
#  ('market', 3),
#  ('complete', 3),
#  ('staying', 3),
#  ('rohit', 3),
#  ('kudathu', 3),
#  ('liked', 3),
#  ('living', 3),
#  ('scored', 3),
#  ('total', 3),
#  ('pitch', 3),
#  ('later', 3),
#  ('single', 3),
#  ('talented', 3),
#  ('starting', 3),
#  ...]

# %%
df['hashtags'].str.replace('[\[,\]]', '')
# Out:
# 0                            'SuriyaFCWarnsBJPnADMKhttps'
# 1                     'SuriyaFCWarnsBJPnADMK' 'Kadamboor'
# 2
# 3                                        'BiggBossTamil3'
# 4
# 10
# 11
# 12
# 13
# 14
# 20                                                'Smule'
# 21
# 22
# 23
# 24
# 30
# 31
# 32
# 33
# 38
# 39
# 40
# 41
# 42
# 43
# 44
# 45
# 54
# 55
# 56
#                               ...
# 1795
# 1798                                       'admissionpic'
# 1799    'Direct' 'UNIVERSITY' 'Admission' 'Admission' ...
# 1800
# 1804
# 1805                'Amul' 'SimpleHomemadeRecipes' 'Chef'
# 1806                'Amul' 'SimpleHomemadeRecipes' 'Chef'
# 1807
# 1812
# 1813                              'MSFTStudentPartnerpic'
# 1814                                      'codeislifepic'
# 1818
# 1819
# 1820    'PES' 'Direct' 'UNIVERSITY' 'Admission' 'Admis...
# 1821    'renewableenergy' 'COVID19' 'cleanenergy' 'tec...
# 1822    'renewableenergy' 'COVID19' 'cleanenergy' 'tec...
# 1823
# 1824                  'admission' 'PES' 'PES' 'Bangalore'
# 1832
# 1833             'EntranceExams' 'PESUniversity' 'PESSAT'
# 1834
# 1835    'Cloud2020Y11' 'InnovationFest' 'AmazingUnisys...
# 1840
# 1841    'PES' 'admission' 'management' 'Management' 'PES'
# 1842
# 1843
# 1844
# 1845            'enlighteninghumanlives' 'thankyouheroes'
# 1846    'Direct' 'UNIVERSITY' 'Admission' 'PES' 'admis...
# 1854
# Name: hashtags, Length: 935, dtype: object

# %%
hashtagfreq = {}
for sentence in df['hashtags']:
    tokens = nltk.word_tokenize(sentence)
    for token in tokens:
        if token not in hashtagfreq.keys():
            hashtagfreq[token] = 1
        else:
            hashtagfreq[token] +=1

# %%
sorted_hashtag=sorted(hashtagfreq.items(),key=operator.itemgetter(1),reverse=True)
sorted_hashtag
# Out:
# [('[', 935),
#  (']', 935),
#  ("'", 768),
#  (',', 448),
#  ("'BiggBossTamil3", 24),
#  ("'PESUniversity", 21),
#  ("'PES", 20),
#  ("'Admission", 13),
#  ("'admission", 10),
#  ("'UNIVERSITY", 9),
#  ("'cheran", 8),
#  ("'pesuniversity", 8),
#  ("'PESUOpenHouse", 8),
#  ("'Smule", 7),
#  ("'PESU", 6),
#  ("'Losliya", 6),
#  ("'Kavin", 6),
#  ("'Bangalore", 6),
#  ("'enlighteninghumanlives", 6),
#  ("'Direct", 6),
#  ("'BiggBossTamil", 5),
#  ("'kavin", 5),
#  ("'hackathon", 5),
#  ("'educationpic", 5),
#  ("'thankyouheroes", 5),
#  ("'bangalore", 4),
#  ("'LearningForLifepic", 4),
#  ("'PESSAT", 4),
#  ("'038", 4),
#  ("'Aatmatrisha", 4),
#  ("'management", 4),
#  ("'technology", 4),
#  ("'Sherin", 3),
#  ("'HourOfCode", 3),
#  ("'Bengaluru", 3),
#  ("'RT", 3),
#  ("'education", 3),
#  ("'Engineering", 3),
#  ("'knowledgetribe", 3),
#  ("'tatacrucible", 3),
#  ("'campusquiz", 3),
#  ("'tccq2020", 3),
#  ("'pesuclubspic", 3),
#  ("'campushiring", 3),
#  ("'COVID19", 3),
#  ("'lawschool", 3),
#  ("'admissions", 3),
#  ("'Management", 3),
#  ("'DMKYouthWingSecretary", 2),
#  ("'kanaa", 2),
#  ("'Viswasam", 2),
#  ("'IntelIndiapic", 2),
#  ("'LosliyaArmy", 2),
#  ("'SRK", 2),
#  ("'pesu", 2),
#  ("'Madhumitha", 2),
#  ("'OviyaArmy", 2),
#  ("'WaitingFor_T_H_A_L_A_60", 2),
#  ("'Basotect", 2),
#  ("'biggbosstamil3", 2),
#  ("'MTVBeats", 2),
#  ("'Vh1Indiapic", 2),
#  ("'PESSAT2020", 2),
#  ("'BBAHEM", 2),
#  ("'Quiz", 2),
#  ("'pesuworkshoppic", 2),
#  ("'CompTIA", 2),
#  ("'zerowastejuice", 2),
#  ("'pesalumnipic", 2),
#  ("'M", 2),
#  ("'stayhomestaysafepic", 2),
#  ("'GyanRoof", 2),
#  ("'datascience", 2),
#  ("'intoAInews", 2),
#  ("'university", 2),
#  ("'studygram", 2),
#  ("'bennydayal", 2),
#  ("'COVIDー19", 2),
#  ("'ai", 2),
#  ("'AI", 2),
#  ("'Amul", 2),
#  ("'SimpleHomemadeRecipes", 2),
#  ("'Chef", 2),
#  ("'renewableenergy", 2),
#  ("'cleanenergy", 2),
#  ("'startups", 2),
#  ("'SuriyaFCWarnsBJPnADMKhttps", 1),
#  ("'SuriyaFCWarnsBJPnADMK", 1),
#  ("'Kadamboor", 1),
#  ("'Udhayanidhi", 1),
#  ("'DMK", 1),
#  ("'kaipullaVIJAY", 1),
#  ("'என", 1),
#  ("'HBDEminentVijay", 1),
#  ("'OhBaby", 1),
#  ("'biggboss3", 1),
#  ("'peing", 1),
#  ("'質問箱", 1),
#  ("'PaadaiKattuTag", 1),
#  ("'therikkudha", 1),
#  ("'Jackpot", 1),
#  ("'Air", 1),
#  ("'mothertongue", 1),
#  ("'HindiImposition", 1),
#  ("'HindiIsNotTheNationalLanguage", 1),
#  ("'Vellaipookkal", 1),
#  ("'Thala", 1),
#  ("'Thalapathy", 1),
#  ("'IntelIndia", 1),
#  ("'Singappenney", 1),
#  ("'SingappenneyFastest600KLikes", 1),
#  ("'usuppu", 1),
#  ("'BiggBossTamil3https", 1),
#  ("'lean", 1),
#  ("'some", 1),
#  ("'johtajuus", 1),
#  ("'kasvuodotukset", 1),
#  ("'Sivakarthikeyan", 1),
#  ("'dsc", 1),
#  ("'google", 1),
#  ("'googledevelopers", 1),
#  ("'Sarkar", 1),
#  ("'Kaappaan", 1),
#  ("'THALAPATHY64", 1),
#  ("'HBDPT", 1),
#  ("'INFTreaty", 1),
#  ("'BiggBossTelugu", 1),
#  ("'KakkoosKavin", 1),
#  ("'sherin", 1),
#  ("'BiggBossTamilpic", 1),
#  ("'Alienstock", 1),
#  ("'nkp", 1),
#  ("'HappyBirthdayYuvan", 1),
#  ("'SanwoOluPayOurBursary", 1),
#  ("'BlindSupport", 1),
#  ("'Simplywaste", 1),
#  ("'BiggBossTamilhttps", 1),
#  ("'Biggboss3tamil", 1),
#  ("'FoamExpopic", 1),
#  ("'independenceday", 1),
#  ("'pesalumni", 1),
#  ("'pes", 1),
#  ("'pesuniversitypic", 1),
#  ("'BiggBosshttps", 1),
#  ("'Thala60", 1),
#  ("'STR", 1),
#  ("'KaviLiya", 1),
#  ("'KavinArmy", 1),
#  ("'HindiDiwas", 1),
#  ("'StopHindiImperialism", 1),
#  ("'StopHindilmposition", 1),
#  ("'தம", 1),
#  ("'Charen", 1),
#  ("'Kasthuri", 1),
#  ("'BiggBossTamilS3", 1),
#  ("'VoteForKavin", 1),
#  ("'artist", 1),
#  ("'show", 1),
#  ("'tallinn", 1),
#  ("'BBNaija", 1),
#  ("'Vanitha", 1),
#  ("'KavLiya", 1),
#  ("'Sandy", 1),
#  ("'Tharshan", 1),
#  ("'MugenRao", 1),
#  ("'Cheran", 1),
#  ("'Avengers", 1),
#  ("'Madhu", 1),
#  ("'BASFPerforMatls", 1),
#  ("'FoamExpo_EU", 1),
#  ("'Foam", 1),
#  ("'PU", 1),
#  ("'CosyPur", 1),
#  ("'Elastocoat", 1),
#  ("'Infinergy", 1),
#  ("'Neopolen", 1),
#  ("'Ultrason", 1),
#  ("'EPP", 1),
#  ("'Manufacturing", 1),
#  ("'Plastic", 1),
#  ("'PerformanceMaterial", 1),
#  ("'losliya", 1),
#  ("'Kavinarmy", 1),
#  ("'EnNenjilKudiIrukumVIJAY", 1),
#  ("'biggbosstamil", 1),
#  ("'Nerpada", 1),
#  ("'Vijay", 1),
#  ("'Ajith", 1),
#  ("'4amanufacturinggmbh", 1),
#  ("'4amillifoam", 1),
#  ("'hardfoamsheetspic", 1),
#  ("'trepo", 1),
#  ("'VetriMaganKavinEntry", 1),
#  ("'savetn", 1),
#  ("'stockmarket", 1),
#  ("'pesueccampuspic", 1),
#  ("'FederalBank", 1),
#  ("'Samarasa", 1),
#  ("'TREMENT", 1),
#  ("'DAIWIK", 1),
#  ("'MAAYA2K19", 1),
#  ("'Law", 1),
#  ("'HourOfCodepic", 1),
#  ("'CauveryDrinkingWater", 1),
#  ("'BacteriaTest", 1),
#  ("'KannadaNews", 1),
#  ("'Tv9Kannadapic", 1),
#  ("'KannadaRajyotsava", 1),
#  ("'morepowertothefuture", 1),
#  ("'Trement", 1),
#  ("'Daiwik", 1),
#  ("'Maaya2k19", 1),
#  ("'DRDO", 1),
#  ("'RSAT", 1),
#  ("'envisage", 1),
#  ("'bmsca", 1),
#  ("'VPIVenkaiah", 1),
#  ("'Samarasa2019", 1),
#  ("'Navaratri2019", 1),
#  ("'pessat", 1),
#  ("'pessat2020", 1),
#  ("'admissions2020", 1),
#  ("'PESuniversity", 1),
#  ("'webVR", 1),
#  ("'connectedThings", 1),
#  ("'mozillahubs", 1),
#  ("'vrpic", 1),
#  ("'PESUECcampus", 1),
#  ("'India", 1),
#  ("'water", 1),
#  ("'healthhttps", 1),
#  ("'TripleJump", 1),
#  ("'Rajyotsava", 1),
#  ("'ArjunaAwards", 1),
#  ("'Atlassian", 1),
#  ("'LastEve", 1),
#  ('8', 1),
#  ("'EndSem", 1),
#  ("'LearnToLearn", 1),
#  ("'AssignmentBaBa", 1),
#  ("'CollegeLife", 1),
#  ("'SBXCorporation", 1),
#  ("'Taj", 1),
#  ("'TajHotels", 1),
#  ("'Kreedotsava2019", 1),
#  ("'PESAlumni", 1),
#  ("'PresidentKovind", 1),
#  ("'ClimateChange", 1),
#  ("'BangaloreEnvironmenttrust", 1),
#  ("'21Nov", 1),
#  ('ವ', 1),
#  ('ಜ', 1),
#  ('ತ', 1),
#  ('ನ', 1),
#  ('ಸ', 1),
#  ("'PhD", 1),
#  ("'Hindustani", 1),
#  ("'Navaratri2019pic", 1),
#  ("'ingenius", 1),
#  ("'Hacktoberfestpic", 1),
#  ("'happydiwali", 1),
#  ("'happydeepavali", 1),
#  ("'NammaMetro", 1),
#  ("'NationalLibraryWeek", 1),
#  ("'FASTAG", 1),
#  ("'RGUHS", 1),
#  ("'BPharma", 1),
#  ("'CMRUniversity", 1),
#  ("'BestPaperPresenterpic", 1),
#  ("'Kudos", 1),
#  ("'grateful", 1),
#  ("'learning", 1),
#  ("'Rust", 1),
#  ("'systems", 1),
#  ("'StopSuperbugs", 1),
#  ("'AMR", 1),
#  ("'OneHealthpic", 1),
#  ("'Bengalurupic", 1),
#  ("'Educationpic", 1),
#  ("'airytails", 1),
#  ("'aeroconferpic", 1),
#  ("'airytailspic", 1),
#  ("'ConQuizTador", 1),
#  ("'Maaya", 1),
#  ("'CEUs", 1),
#  ("'PDHs", 1),
#  ("'educational", 1),
#  ("'webinars", 1),
#  ("'tutorials", 1),
#  ("'PlainTalk", 1),
#  ("'Amazon", 1),
#  ("'blooddonation", 1),
#  ("'WaterHeroes", 1),
#  ("'republictvpic", 1),
#  ("'samahitharesearchsolutionspic", 1),
#  ("'rememberingmartyrs", 1),
#  ("'pulwamaattack", 1),
#  ("'forthemartyrs", 1),
#  ("'withthejawans", 1),
#  ("'Startup", 1),
#  ("'pesusportspic", 1),
#  ("'10YearsBack", 1),
#  ("'kannada", 1),
#  ("'Divyaspandana", 1),
#  ("'Ramyapic", 1),
#  ("'Samarpana", 1),
#  ("'pesuiopic", 1),
#  ("'newbeginingsendlesspossibilities", 1),
#  ("'atithya2020", 1),
#  ("'competitionseason", 1),
#  ("'competitionpic", 1),
#  ("'software", 1),
#  ("'Bangalorepic", 1),
#  ("'NationalTourismDay", 1),
#  ("'Riviera", 1),
#  ("'basketball", 1),
#  ("'throwball", 1),
#  ("'tabletennis", 1),
#  ("'chess", 1),
#  ("'Cybersecurity", 1),
#  ("'Cybersecuritypic", 1),
#  ("'bcom", 1),
#  ("'universityrankpic", 1),
#  ("'Samahitharesearchsolutions", 1),
#  ("'PESITpic", 1),
#  ("'good", 1),
#  ("'eatraja", 1),
#  ("'aatmatrisha2020", 1),
#  ("'pesuworkshop", 1),
#  ("'WildKarnataka", 1),
#  ("'Tezos", 1),
#  ("'jobsforfreshers", 1),
#  ("'TeamAeolus", 1),
#  ("'happynewyear2020", 1),
#  ("'HappyNewYear", 1),
#  ("'HappyNew2020pic", 1),
#  ("'campusplacements", 1),
#  ("'collegepic", 1),
#  ("'hyderabad", 1),
#  ("'game", 1),
#  ("'Navy", 1),
#  ("'TeamHaya", 1),
#  ("'RepublicDay", 1),
#  ("'PESalumni", 1),
#  ("'pesualumnimeet", 1),
#  ("'pesalumnimeetpic", 1),
#  ("'Python", 1),
#  ("'MCA", 1),
#  ("'ncet", 1),
#  ("'PESUIO", 1),
#  ("'MachineLearning", 1),
#  ("'GreatLearning", 1),
#  ("'tbbpress", 1),
#  ("'news", 1),
#  ("'updates", 1),
#  ("'updatednews", 1),
#  ("'latestnews", 1),
#  ("'bulletinboards", 1),
#  ("'arrangement", 1),
#  ("'Universities", 1),
#  ("'Data", 1),
#  ("'Science", 1),
#  ("'classification", 1),
#  ("'KSURF", 1),
#  ("'Accessiblepic", 1),
#  ("'EGuestLecture", 1),
#  ("'zerowaste", 1),
#  ("'distancelearning", 1),
#  ("'elearning", 1),
#  ("'WomensDay", 1),
#  ("'happyugadi", 1),
#  ("'Btech", 1),
#  ("'AbhishekRoy", 1),
#  ("'pesbangalore", 1),
#  ("'mba", 1),
#  ("'pgdm", 1),
#  ("'aicte", 1),
#  ("'cat", 1),
#  ("'mat", 1),
#  ("'xat", 1),
#  ("'cmat", 1),
#  ("'gmat", 1),
#  ("'atma", 1),
#  ("'nmat", 1),
#  ("'mbaadmission", 1),
#  ("'pgdmadmission", 1),
#  ("'managementpic", 1),
#  ("'COVIDー19https", 1),
#  ("'medicalcamp", 1),
#  ("'bethebridge", 1),
#  ("'doyoupromisetobewild", 1),
#  ("'vf", 1),
#  ("'namah", 1),
#  ("'VidhanaSoudha", 1),
#  ("'drmrdpic", 1),
#  ("'techbytesquiz", 1),
#  ("'sjbitpic", 1),
#  ("'WorldWildlifeDay", 1),
#  ('6', 1),
#  ("'keerthiroyalpalms", 1),
#  ("'Recap", 1),
#  ("'DSC", 1),
#  ("'Hackathon", 1),
#  ("'machinelearning", 1),
#  ("'AmitShahIstifaDo", 1),
#  ("'NationalScienceDay", 1),
#  ("'dotSlash", 1),
#  ("'organizers", 1),
#  ("'volunteers", 1),
#  ("'sponsors", 1),
#  ("'studygrampic", 1),
#  ("'Kuchipudi", 1),
#  ("'AWS", 1),
#  ("'Cloud", 1),
#  ("'Mysuru", 1),
#  ("'Mandya", 1),
#  ("'COVID2019india", 1),
#  ("'CoronavirusOutbreakindia", 1),
#  ("'Donations", 1),
#  ("'CMReliefFund", 1),
#  ("'ChineseVirus19", 1),
#  ("'COVID19Hindustan", 1),
#  ("'StudyIdeaspic", 1),
#  ("'WGSHAQuest", 1),
#  ("'BBMP", 1),
#  ("'pesuaspiration", 1),
#  ("'pesupharmacypic", 1),
#  ("'vlogs", 1),
#  ("'music", 1),
#  ("'concerthttps", 1),
#  ("'stageselfie", 1),
#  ("'aatmatrisha", 1),
#  ("'REVAUniversity", 1),
#  ("'thaikuddambridge", 1),
#  ("'MonitorWorld", 1),
#  ("'JDavisProsoundAndLighting", 1),
#  ("'GraflexInc", 1),
#  ("'Giglife", 1),
#  ("'CMECE", 1),
#  ("'SFI", 1),
#  ("'SwimmingChampionship", 1),
#  ("'StayHomeStaySafepic", 1),
#  ("'9PM9MIN", 1),
#  ("'stayhomestaysafe", 1),
#  ("'VirtualDiscussion", 1),
#  ("'Panel", 1),
#  ("'WGSHA", 1),
#  ("'PEU", 1),
#  ("'Education", 1),
#  ("'Hospitality", 1),
#  ("'Culinary", 1),
#  ("'Manipal", 1),
#  ("'MAHEpic", 1),
#  ("'hospitalityindustry", 1),
#  ("'culinary", 1),
#  ("'Covid19", 1),
#  ("'CoronaVirus", 1),
#  ("'wuhancoronavirushttps", 1),
#  ("'Lastdate", 1),
#  ("'Slotbookingpic", 1),
#  ("'letstaffstayhome", 1),
#  ("'PESUNIVERSITY", 1),
#  ("'StayHomeSaveLives", 1),
#  ("'Photography", 1),
#  ("'PESUGuestLectures", 1),
#  ("'travel", 1),
#  ("'tourism", 1),
#  ("'shotononeplus", 1),
#  ("'oneplus6", 1),
#  ("'mtech", 1),
#  ("'datasciencecourse", 1),
#  ("'machinelearningtraining", 1),
#  ("'upskill", 1),
#  ("'courses", 1),
#  ("'sih20", 1),
#  ("'record", 1),
#  ("'memesdaily", 1),
#  ("'sundayvibes", 1),
#  ("'through", 1),
#  ("'rcpesu", 1),
#  ("'environmentconservation", 1),
#  ("'eidmubarak", 1),
#  ("'startup", 1),
#  ("'nopollution", 1),
#  ("'Auto", 1),
#  ("'DirectAdmissionPESUniversity", 1),
#  ("'PESIT", 1),
#  ("'PESSATEntrance", 1),
#  ("'covidmove", 1),
#  ("'covid19", 1),
#  ("'coronavirus", 1),
#  ("'ieeepic", 1),
#  ("'fee", 1),
#  ("'NRIQuotaAdmissioninPESUniversityBangalore", 1),
#  ("'directadmissioninmanagementquotainPESUniversity", 1),
#  ("'DirectAdmissioninPESUniversityBangalore", 1),
#  ("'topprivateengineeringcollegesinBangalore", 1),
#  ("'BtechCollegepic", 1),
#  ("'mechanical", 1),
#  ("'admissionpic", 1),
#  ("'MSFTStudentPartnerpic", 1),
#  ("'codeislifepic", 1),
#  ("'EntranceExams", 1),
#  ("'Cloud2020Y11", 1),
#  ("'InnovationFest", 1),
#  ("'AmazingUnisyspic", 1)]

# %%
most_freqword = sorted_wordfreq[0:20]
plt.bar(range(len(most_freqword)), [val[1] for val in most_freqword], align='center')
plt.xticks(range(len(most_freqword)), [val[0] for val in most_freqword])
plt.xticks(rotation=90)
plt.show()

# %%
most_freqht = sorted_hashtag[6:25]
plt.bar(range(len(most_freqht)), [val[1] for val in most_freqht], align='center')
plt.xticks(range(len(most_freqht)), [val[0] for val in most_freqht])
plt.xticks(rotation=90)
plt.show()
